# %% [markdown]
# <div style="text-align:center">
# <img src="img/etlintro.png">
# </div>

# %% [markdown]
# # Introduction
#
# Here I will investigate ETLS basics using Python and A.I
#
# # Summary
#
#
# 01. <b> </b>
#     - Abstract
#     - Instance
#     - Math model
#     - Docplex solution

# %% [markdown]
# # Queues analysis and optimizations.
#
# ## Introduction
#
# Running a M/M/S queue simulation allows you to make arrangements so as not to end up with endless queues, which are detrimental to customers.
# First, we have the statistics.
# Secondly, it is possible to use optimization to minimize the waiting time.
#
#
# Creation in progress!
# Global study proposed by <b>Estelle Derrien - Github estellederrien</b>
#
#
# # Summary
#
# - 1. The M/M/S model (also called M/M/C)
#         - Role and parameters
#         - Kendall's notation
#         - Questions resolved by queuing theory.
#         - An example M/M/1
#           - Statistical results with Python
#         - A queue at the doctor's (Example M/M/1)
#           - Statistical results with Python
#         - An example M/M/2
#           - Statistical results with Python
#           - How to calculate arrival and service rates?
#
# - 2. The model x * M/M/1
#         - Role and parameters
#         - Our basic problem
#         - Mathematical modeling
#         - Probabilities with Poisson's law
#         - Solution and results with Python

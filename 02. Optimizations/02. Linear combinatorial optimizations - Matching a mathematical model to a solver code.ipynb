# %% [markdown]
# <div style="text-align:center">
# <img src="img/intro_correspondre.png">
# </div>

# %% [markdown]
# ## Introduction.
#
# <i><span style="color:blue"> In life, we often have to make decisions, often it's a single decision, or a little more complicated, it can depend on another decision, for example, "should I buy this car?" and “If I buy it, will I have to replace the carburetor?” But, in operations research, there are hundreds of decisions to be made, and only a computer and the appropriate algorithm will be able to solve this type of problem, It's simply impossible to solve with your brain.
# This notebook is an introduction to the exciting world of operations research.</span></i>
#
# We will analyze the methods to match a given mathematical model to a Python solver code. In other words, how to go from one to the other. This in the context of combinatorial optimizations.
# I start with a total beginner level, then I complicate things as the notebook progresses.
# I will create a second intermediate level notebook, with uncertainty models, using probabilities in optimizations, when this one is finished.
#
# *** CREATION IN PROGRESS ***<br>
# Notebook created by GITHUB ESTELLE DERRIEN

# %% [markdown]
# ## Summary
#
# 1. <b> Mathematical symbols and vocabulary to know. </b>
# ## Linear combinatory problems
# 2. <b> Begginer method using a simple problem </b>
#     - 2.1 Presentation of the product mix problem
#     - 2.2 Modeling of a basic instance using hard values
#     - 2.3 Python Pulp solution
#     - 2.4 Cplex solution
# 3. <b> Extension of our problem and Σ summation symbol discovery . </b>
#     - 3.1 Presentation of the problem in a table
#     - 3.2 Mathematical modeling and difference between instance and model
#     - 3.3 Programming of the Σ summation symbol in the Python solver
#         - With Python Pulp
#         - With Python Cplex
#         - With GLPK online command
# 4. <b> Getting Familiar with Aij constraints writing using a simple example taken from Hillier </b>
#     - 4.1 Presentation of the problem in a table
#     - 4.2 Mathematical modeling and nomenclature
#     - 4.3 Aij solution and programming with Python Pulp
#     - 4.4 Comparing the Hillier Lingo solver solution to the Python Pulp one.
# 5. <b> Getting Familiar with an objective function including a Σ  and a cost subtraction. </b>
#     - 5.1 Presentation of the problem in a table
#     - 5.2 Mathematical modeling
#     - 5.3 Python Pulp solution
# 6. <b>Getting familiar with double summation writing ΣΣ and Xij decisions variables</b>
#     - 6.1 Presentation of the Aarvik and Randolph (1975) transportation problem
#     - 6.2 Mathematical modeling focused on the double summation and Xij decisions variables
#     - 6.3 Python Pulp solution
#     - 6.4 Comparing the Aarvik and Randolph solution to the Python Pulp one.
# 7. <b>Getting familiar with logical/conditional constraints</b>
#     - 7.1 Best available ressources on the internet and table summaries
#     - 7.2 Introduction
#         - 7.2.1 Presentation of the capital budgeting problem
#         - 7.2.2 Mathematical modeling
#         - 7.2.3 Solution using Python Pulp and Book's Excel solution comparison
#         - 7.2.4 Mathematical modeling of conditional constraints.
#             - <b>Association</b>
#                 - Solution using Python Pulp
#             - <b>Exclusion</b>
#                 - Solution using Python Pulp
#             - <b>At least</b>
#                 - Solution using Python Pulp
#
#             - <b>Prerequisite</b>
#                 - Solution using Python Pulp
#     - 7.3 <b>IF-THEN</b>
#         - 7.3.1 Presentation of the Fixed cost cars problem
#             - Mathematical modeling of IF-THEN using an IBM doc.
#             - Solution using Ibm Cplex internal IF THEN feature.
#             - Solution using Python Pulp using a first BIG M Method.
#         - 7.3.2 Presentation of the  Alex Fleischer IF-THEN Bus Problem
#             - Mathematical modeling of IF-THEN constraints.
#             - Solution using Python Pulp using a BIG M Method.
#             - Solution using Ibm Cplex using a BIG M Method.
#             - Solution using Ibm Cplex internal IF THEN feature.
#         - 7.3.3 Extension of the Fixed cost cars problem
#             - Mathematical modeling of IF-THEN using an IBM doc.
#             - Solution using Ibm Cplex internal IF THEN feature.
#             - Solution using Python Pulp the  BIG M Method.
#     - 7.4 <b>OR</b>
#         - OR constraint formulation.
#         - Solution using Ibm Cplex OR internal feature.
#         - Solution using a BIGM Python Pulp method.
#     - 7.5 <b>AND</b>
#         - AND constraint formulation.
#         - Solution using Ibm Cplex AND internal feature.
#         - Solution using a BIGM Python Pulp method.
#     - 7.6 <b>Restricting a variable to a set of values.</b>
#         - Restricting constraints values to a set formulation.
#         - Solution using Python Pulp
#     - 7.7 <b>Restricting a variable to take on discontinuous values.</b>
#         - Formulation.
#         - Solution using Python Pulp
#     - 7.8 <b>Adding penalty constraints.</b>
#         - Formulation.
#         - Solution using Python Pulp
#         - SOlution using Cplex
#     - 7.9 <b>Discontinuous and piecewize costs functions.</b>
#         - Shipping cost and production mix constraints differences examples.
#             - Linear
#             - Concave
#             - Convex
#             - Discontinuous
#                 - Solution using Ibm Cplex internal commands
#                 - Solution using Python Pulp and Big M Method
#             - Piecewize
#                 - Solution using Ibm Cplex internal commands
#                 - Solution using Python Pulp and Big M Method
#
# 8. <b> Modeling of a Knapsack problem </b>
#     - 8.1 Instance
#     - 8.2 Mathematical modeling
#     - 8.3 Python Pulp solution
# 9. <b> Modeling of a Blending problem </b>
#     - 9.1 Instance : The Pittsburgh Steel Problem by Lindo
#     - 9.2 Mathematical modeling
#     - 9.3 Python Pulp solution
# 10. <b> Modeling of a set cover problem </b>
#     - 10.1 Instance : Wikipedia real set cover problem
#     - 10.2 Mathematical modeling
#     - 10.3 Python Pulp solution
#     - 10.3 Instance : Build a connected facility
#     - 10.4 Mathematical modeling
#     - 10.5 Python Pulp solution
#
# 11. <b> Employees tasks assignment problem </b>
#     - 11.1 Instance : Assignment problem by Excel Easy
#     - 11.2 Mathematical modeling
#     - 11.3 Python Pulp solution
#
# 13. <b> Modeling of a Project scheduling problem</b>
#
#     - 13.1 Instance
#     - 13.2 Mathematical modeling
#     - 13.3 Python Cplex solution
#     - 13.4 Python Pulp solution
#     - 13.5 Instance of the ressource constrained version RSPSP
#     - 13.7 Mathematical modeling
#     - 13.8 Python Pulp solution
#
# 14. <b> Modeling of a maximum flow problem</b>
#     - 14.1 Instance : Max flow problem by Excel Easy
#     - 14.2 Mathematical modeling
#     - 14.3 Python Pulp and Google OR solution
#
#
#
# 15. <b> Modeling of a multiperiod production and storage problem </b>
#     - 15.1 Instance
#     - 15.2 Mathematical modeling
#     - 15.3 Python Pulp solution
#
# 16. <b>Optimal employees shift scheduling</b>
#     - 16.1 Instance
#     - 16.2 Mathematical modeling
#     - 16.3 Python Pulp solution
# 17. <b> Modeling of a single machine scheduling problem</b>
#     - 17.1 Instance
#     - 17.2 Mathematical modeling
#     - 17.3 Python Pulp solution
# 18. <b> Modeling a chemistry combinatorial optimization  </b>
#     - Presentation of the Mac Graw Book problem BOILER/TURBO-GENERATOR SYSTEM
#     - Mathematical modeling
#     - Python Pulp or Cplex solution
# 19. <b> Modeling a petroleum combinatorial optimization </b>
#     - Presentation and Kirchhoff constraints
#     - Mathematical modeling
#     - Python Pulp or Cplex solution
# 20. <b> Modeling an uncapacited transport problem </b>
#     - Presentation
#     - Mathematical modeling
#     - Python Pulp or Cplex solution
# 21. <b> Modeling a capacited transport problem  </b>
#     - Presentation of the Dasking problem (2013)
#     - Mathematical modeling
#     - Python Pulp or Cplex solution
#         - Using hard values
#         - Using iterations
# 22. <b> Modeling a Bin Packing problem  </b>
#     - Presentation and differences
#     - Mathematical modeling
#     - Python Pulp or Cplex solution
#
# 23. <b> Getting familiar with sensitivity analysis
#     - Reduced costs
#     - The Shadow Price
#     - Slacks variables
# 24. <b> Getting familiar with variables relaxations</b>
#
# 25. <b> Linearizations </b>
#     - Linearization technics using the AIMMS modeling guide and Ling-Chieh Kung technics
#     - Objective linearizations
#     - Constraints linearizations
#     - Examples using Python solvers
#
#
# 26. <b> Apendix </b>
# - Importing a data instance from an Excel file
# - Importing a data instance from a Database

# %% [markdown]
# # 1. Mathematical symbols and vocabulary to know:
#
#
#
# <div style="text-align:center">
# <img src="img/ensemble-plat-moderne-de-thème-d-éducation-d-illustration-de-vecteur-de-symboles-mathématiques-d-ic-nes-plates-colorées-de-86917716.webp" width="100">
# </div>
#
# - Symbol <b> Σ </b> (sigma), makes it possible to simplify the writing of an addition.
#
# - Symbol <b> ∏ </b>  makes it possible to simplify the writing of an multiplication.
#
# - Symbol <b> ∈ </b> means "belongs to", we use it when we first defined a set S {x1, x2 ... xn}
#
# - Symbol <b> ∀ </b> (quantifier) ​​means "for all".
#
# - An <b> Aij matrix </b>: i is the row, j it's the column.So if we are told about value A14, this is the value of row 1 column 4.
#
# - An <b> Objective function </b>: it is intended to be minimized or maximized, when the solver calculates the best values ​​of the decision variables
#
# - <b>Decision variables </b>: a decision variable contains a value which will then be calculated by the solver to be the best possible value to minimize or maximize an objective function (that's it, optimization).The best known algorithm is the simplex.
#
# - <b> "subject to"  </b> means that the objective function is subject to constraints that we write under the "subject to" sentence.
#
# - <b> ℕ </b> is the set of positive integers including 0,  <b> ℕ </b> ∗  omens zero. It is generally used to specify the nature of the decision variables, they can therefore be integer, continuous or binary.
#
# - <b> "Expressed in kg" </b> This formulation "expressed in" is important because in operations research, we are constantly juggling with S.Is, the international system for the rating of internationally recognized units.Omitting this specification can lead to many problems, especially during optimizations in percentages, or when it is necessary to transpose into another S.I, example, of kilos in tons, from euros to dollars.
#
# - <b> Quick advice </b> You can't multiply decisions variables or use powers and roots when you deal with a linear optimization.

# %% [markdown]
# # <b>2. First method using a simple problem </b>
#
#  We're going to take a fairly simple production mix model.
#  In beginner problems, at the beginning, we don't have to use the summation symbol, since we generally have few variables, by deduction, we don't have to iterate with the solver. It is therefore much simpler to
#  understand, at the beginning

# %% [markdown]
# ## 2.1 Presentation of the production mix problem
#
# <div style="text-align:center">
# <img src="img/000171013_896x598_c.jpg" width="500"/>
# </div>
#
# - A company produces car A and car B.
# - Car A requires 20 units of K supplies and 10 units of Z supplies.
# - Car B requires 18 units of K supplies and 8 units of Z supplies.
# - There are 5000 units of K supplies in inventory and 6000 units of Z supplies in inventory.
# - Car A has given a profit of 20,000 euros, and car B provides a profit of 18,000 euros.
#
# What cars should the company provide in order to <b> maximize its profit </b>, subject to <b> inventory constraints </b>?

# %% [markdown]
# So here, in this problem, we can clearly see that there are few decision variables involved and few constraints. No reason to express the mathematical model with summation symbols, and to do iterations in the Python modeler code.
#
#
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#
# </table>

# %% [markdown]
# ## 2.2 Modeling of a basic instance using hard values
#
# Let
#
# - A be the number of A car units to be produced (it is a decision variable)
# - B be the number of B car units to be produced (it is a decision variable)
#
# <b> The objective function R </b> is to maximize profit: <br>
#
#
# $$
# Max (R) = 20000A + 18000B
# $$
#
# <b> Constraints </b> are inventory constraints: <br>
#
# K inventory : <br>
# $$
# 20A + 18B <= 5000
# $$
#
# Z inventory :<br>
# $$
# 10A + 8B <= 6000
# $$

# %% [markdown]
# ## Let's write the instance
#
# $$
# Max (R) = 20000A + 18000B
# $$
# $$
# s.t
# $$
#
# $$
# 20A + 18B <= 5000
# $$
# $$
# 10A + 8B <= 6000
# $$
#
# $$
# with
# $$
#
# $$
# {A,B} ∈ ℕ
# $$

# %% [markdown]
# ## 2.3 Python Pulp solution
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>
#
# Here is a basical optimization code, done with Python Pulp Modeler.

# %%
# Basic method:
# -----------------------------------
# Import from Python Pulp
# -------- ---------------------------
from pulp import *
# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )
# -----------------------------------
# Decision variables
# -----------------------------------
A = LpVariable ( "A" , lowBound = 0 , cat = 'Integer' ) 
B = LpVariable ( "B" , lowBound = 0 , cat = 'Integer' ) 
# -----------------------------------
# Objective function R
# -----------------------------------
model += 20000 * A + 18000 * B
# -----------------------------------
# Constraints
# -----------------------------------
model += 20 * A + 18 * B <= 5000 , "k_inventory"
model += 10 * A + 8 * B <= 6000 , "z_inventory"
# -----------------------------------
# Solution
# ----------- ------------------------
model.solve ()

#  Printing variables that have their values optimized
for v in model . variables ():
    print( v . name , "=" , v . varValue )

# optimized objective function value is printed to the screen 
print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# A = 7.0
# B = 270.0
# Maximized total profit =  5000000.0

# %% [markdown]
# ## 2.4 Solution using CPLEX
#
# <div style="text-align:center">
# <img src="img/IBM_CPLEX_0.png">
# </div>
#
#
# Let's see how syntax differs from Python Pulp.

# %%
# Basic method:
# -----------------------------------
# Import from CPLEX
# -------- ---------------------------
import cplex
import docplex.mp
from docplex.mp.model import Model

# -----------------------------------
# Setting prob
# -----------------------------------
model = Model(name='Problem', log_output=True)

# -----------------------------------
# Decision variables
# -----------------------------------
A = model.integer_var(name='A')
B = model.integer_var(name='B')

# -----------------------------------
# Objective function R
# -----------------------------------
model.maximize(20000 * A + 18000 * B)

# -----------------------------------
# Constraints
# -----------------------------------
model.add_constraint(20 * A + 18 * B <= 5000)
model.add_constraint(10 * A + 8 * B <= 6000)

# -----------------------------------
# Solution
# ----------- ------------------------
model.parameters.mip.display.set(0)
sol_model = model.solve()
model.print_solution()
# Out:
# Version identifier: 22.1.1.0 | 2023-02-09 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_MIP_Display                             0
# objective: 5000000
# status: OPTIMAL_SOLUTION(2)
#   A=250

# %% [markdown]
# # <b>3. Extension of our problem and Σ summation symbol discovery .</b>
#
# Now let's say the company produces 12 different cars, each requiring a different quantity of supply K and Z, and each providing a different profit. The goal is still to determine which cars are best to produce, in
# order to maximize our profit subject to inventory constraints.
#
# Isn't it boring to retype each value by hand? Yes, it is boring.
#
# Wouldn't it be more convenient to use the summation mathematical symbol when we are going to write the mathematical model, and to iterate over an array in the Python solver code? This is in order to synthesize the expression of our optimization? Which will allow us to communicate easily and internationally about our optimization, and to be understood quickly?
#
# So now let's try to model our mathematical optimization model, by deducing it from our data. We will use the summation symbol, then, we will iterate in the Python code, to obtain our final linear optimization.

# %% [markdown]
# ## Table of supplies needed for the 12 cars.

# %% [markdown]
# <div style="text-align:center">
# <img src="img/car-table.png" />
# </div>

# %% [markdown]
# ## We deduce the mathematical instance from this.
#
# Let's write this instance in hard copy, in order to understand how boring it is.
#
# Let
# - A be the number of A car units to be produced (it is a decision variable)
# - B be the number of B car units to be produced (it is a decision variable)
# - C be the number of C car units to be produced (this is a decision variable)
# - D be the number of D car units to be produced (this is a decision variable)
# - E be the number of E car units to be produced (it is a decision variable)
# - F be the number of F car units to be produced (it is a decision variable)
# - G be the number of G car units to be produced (this is a decision variable)
# - H be the number of H car units to be produced (this is a decision variable)
# - I be The number of I car units to be produced (this is a decision variable)
# - J be the number of J car units to be produced (this is a decision variable)
# - K be the number of K car units to be produced (this is a decision variable)
# - L be the number of L car units to be produced (this is a decision variable)
#
# <b>The objective function that we can call R</b> is to maximize the profit:<br>
# Max(R) = 20000A + 18000B + 17000C + 21000D + 24000E + 18500F + 20500G + 18500H + 18900I + 21000J + 20500K + 8000L<br><br>
#
# <b>The constraints are the inventory constraints:</b><br>
# K inventory:<br>
# 20A + 18B + 9C + 20D + 22E + 10F + 20G + 12H + 15I + 22J + 21K + 5L <= 5000<br><br>
# Z inventory:<br>
# 10A + 8B +8C + 19D + 24E + 10F + 19G + 10H + 12I + 18J + 20K + 4L <= 6000

# %% [markdown]
# ## Difference between an instance and a model
#
# What we defined just above is an <b>instance</b> . Let's now see how to model the <b>mathematical model</b> synthesized, from this instance, in the next chapter.

# %% [markdown]
# ## The mathematical model is modeled using the summation symbol and the indices.
#
# <div style="text-align:center">
# <img src="img/modeles-mathematiques-intelligence-artificielle.jpg" width="500"/>
# </div>
#
#
# We can clearly see that above, we have sums, and that writing them by hand is prone to error.
#
# - We note that there are <b> sets </b> that can be <b> Indexed </b>: cars, K supplies, Z supplies, profits.
#
# - We notice that our Table of supplies needed for the 12 cars is similar to <b> an Aij matrix </b>.
#
# <b> Reminder </b>: Let Aij be a matrix: i is the row number, j is the column number. So if we are told about the value A14, it is the value of row 1 column 4 of the matrix.
#
# - We will therefore create <b>a mathematical model</b> , using sets and summation symbols, which will summarize our problem in a simpler and more understandable way; this will be the synthesized version of our optimization.
#
#
# Then, we can freely create <b>instances</b> of this model with different datas each time, possibly coming from databases. In addition, this model can be used with all solvers on the market, including Excel.
#
# Now let us consider the sets:
#
# - <b>Cj</b> for cars, {A...L} indexed by j
# - <b>Kj</b> for supplies K, {20...5} indexed by j
# - <b>Zj</b> for supplies Z, {10...4} indexed by j
# - <b>Pj</b> for profits {20000...8000} indexed by j
#
# We will already use only the sets to learn how to write the mathematical model, and not the matrix; we will do that later, because it is more complicated to read.
#
# If we want to rewrite the synthesized objective function that maximizes the benefit of the sum of cars:<br>
# Max(R) = 20000A + 18000B + 17000C + 21000D + 24000E + 18500F + 20500G + 18500H + 18900I + 21000J + 20500K + 8000
#
# We write it:
# $$
# Max (R) = \sum_{j=1}^{C} P_{j}.C_{j}
# $$
#
# - Why do we index with the letter j? Because by convention, this designates the column of a matrix. You have to imagine in your head iterating over each value and that the value of the letter j is incremented.
#
# If we want to rewrite the first inventory constraint K, in a synthesized way:<br>
# 20A + 18B + 9C + 20D + 22E + 10F + 20G + 12H + 15I + 22J + 21K + 5L <= 5000
#
# We write it :
# $$
#  \sum_{j=1}^{K} K_{j}.C_{j} <= 5000
# $$
#
# If we want to rewrite the second inventory constraint Z, in a synthesized way:<br>
# 10A + 8B +8C + 19D + 24E + 10F + 19G + 10H + 12I + 18J + 20K + 4L <= 6000
#
# We write it:
# $$
#  \sum_{j=1}^{Z} Z_{j}.C_{j} <= 6000
# $$
#
# We arrive at our following synthesized optimization model:
#
# $$
# Max (R) = \sum_{j=1}^{C} P_{j}.C_{j}
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{K} K_{j}.C_{j} <= 5000
# $$
# $$
#  \sum_{j=1}^{Z} Z_{j}.C_{j} <= 6000
# $$
# $$
#  Cj \in ℕ
# $$

# %% [markdown]
# <b>Now, constraints are not written like this usually, but refer to the matrix: Source: Linear Programming with Excel by Christian Prins and Marc Sevaux Page 58 and Courses from Taiwan university and Hillier and many others...</b>
# We can further reduce our model by reducing the writing of constraints in this way:
#
# $$
#   \sum_{j=1}^{C} a_{ij}.C_{j} <= S_{i}
# $$
#
# where :
#
# - aij means that we consider each supply value for each car, for each existing supply row in our data matrix.
# - Si means that the value of each current stock is contained in a vector indexed by i, instead of being hard-coded, S is therefore the set of inventory
#
# but, don't worry, we'll study a real case of this Aij notation in chapter 4...

# %% [markdown]
# ## Now we use Python solvers, wishing to find a solution.
#
# Let's take the objective function of our model:
# $$
# Max (R) = \sum_{j=1}^{C} P_{j}.C_{j}
# $$
#
# So P is the set of profits. So C is the set of cars.<br>
# This will involve <b>rewriting this summation symbol</b> of the mathematical model, with <b>several Solvers</b>, in <b>Python language</b> .<br>
# The syntax is unfortunately different between solvers, but is often somewhat similar.<br>
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>
#
#
# We must of course first enter  our data initial table in Python, before manipulating them with Solvers, this data is an instance of our optimization . There are several ways to enter this data, and this
# then influences the syntax when manipulating the solver, however, we generally find the same syntax, on StackOverflow and by the author of Python Pulp.
# It must look like the mathematical model as much as possible, of course it is necessary to assign strictly the same letters to the sets as in the mathematical model and its nomenclature, this is
# MANDATORY.
#
#
# ## Here is our instance ( data )

# %%
# -----------------------------------
# Data - Instance
# ----------- ------------------------
# Cars names
C = [ 'A' , 'B' , 'C' , 'D' , 'E' , 'F' , 'G' , 'H' , 'I' , 'J' , 'K' , 'L' ]
# Profits per car
P = { 'A' : 20000 , 'B' : 18000 , 'C' : 17000 , 'D' : 21000 , 'E' : 24000 , 'F' : 18500 , 'G' : 20500 , 'H' : 18500 , 'I' : 18900 , 'J' : 21000 , 'K' : 20500 , 'L' : 8000 }

# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )

# -----------------------------------
# Creation of Decision Variables
# -----------------------------------
# We stipulate that these are integer variables, normal, since they are cars, they can't be separable.
c = LpVariable . dicts ( "cars" , C , lowBound = 0 , cat = 'Integer' )

# %% [markdown]
# Then, Come on, let's go, for the first time, we recreate the objective function of our mathematical model:
#
# $$
# Max (R) = \sum_{j=1}^{C} P_{j}.C_{j}
# $$
#
# - With Python Pulp

# %%
# -----------------------------------
# Objective function
# -----------------------------------
model += lpSum([P[j] * c[j] for j in C ]), "MAXIMIZE_PROFIT_R_FUNCTION" 

# -----------------------------------
# Explanation
# -----------------------------------
# The previous line dynamically recreates:
# Max(R) = 20000A + 18000B + 17000C + 21000D + 24000E + 18500F + 20500G + 18500H + 18900I + 21000J + 20500K + 8000L
# using iterations, you have to visualize it in your head. It is the equivalent of our mathematical model
# and its summation symbol.

# %% [markdown]
# - With Cplex

# %%
# Comin soon

# %% [markdown]
# - With GLPK, on the command line

# %%
# Comin soon

# %% [markdown]
# Ok, in chapter 3 , we won't bother about the solution, the goal was to learn to go from a mathematical model, to a python code.
# Starting at chapter 4, we'll take care about the solution and compare it to real officials books solutions, to make sure it's identical.

# %% [markdown]
# # <b>4. Familiarize yourself with the Aij constraints writing  with a simple example taken from Hillier</b>
#
# ## 4.1 Presentation of the problem in a table
#
# We have seen previously that the modeling of constraints in the mathematical model often uses the expression aij in the summation symbol. This is a, indexed by i and j. This i means that we iterate on the rows, in addition to iterating on the columns j. This is therefore a double treatment.
#
# Let's take this simple case of production mix optimization, present in the book Hillier, Introduction to operation research 7th edition - page 82
#
# <div style="text-align:center">
# <img src="img/factory.webp" width="500"/>
# </div>
#
# The objective is to maximize profit under the constraint of available production time :

# %% [markdown]
# <div style="text-align:center">
# <img src="img/hillier-1.png" />
# </div>

# %% [markdown]
# ## 4.2 Mathematical modeling
#
# As usual, we first identify the sets that are involved in our mathematical model.
# Let's already try to model the <b>objective</b> function R which will maximize the profit:
#
# - Why are the products P0j the decision variables?
# Because their respective number will be calculated, in real time, by the solver to obtain the maximum profit under constraints . We will create the set Xj (x1,x2..xn) which are theses decision variables, the j is in index, because we have the columns P01, P02, P03 and P04. By convention, generally, the decision variables are called x, and we use j because by convention, we designate columns. Why not calling this set P, like ' Products' ? Because We need the P letter for the Profit set.
#
# - We see that we have the set Pj(p1,p2..pn) which are the constant values of profit per product supplied. So, here it's the same, we use the index j because by convention, it designates the columns.
#
# We therefore arrive at this objective function, as in Hillier's book:
#
# $$
# Max (R) = \sum_{j=1}^{4} p_{j}.x_{j}
# $$
#
# We notice that we put 4 at the top of the summation symbol, as a limit, but we could also have put X, to obtain a more generic iteration, because this implies the set X which contains 4 values, but could contain
# more.
#
# <b> Now we come to the important part, the constraints.</b>
#
# We see in our table that we have 3 lines of constraints that we can index by i. By convention, i designates the line numbers. Therefore, we will not write a summation symbol per line, which would weigh down our final model, but we will introduce aij which means that we <b>automatically iterate by line and by columns at the same time</b>, so we model our constraints like this, as in Hillier's book:
#
# $$
# \sum_{j=1}^{4} a_{ij}.x_{j} <= b_{i}\thinspace\thinspace\thinspace for \thinspace i = 1,2,3
# $$
#
# We notice that we have an additional (mandatory) piece of information "For i = 1,2,3", which is logical since there are 3 lines in all. The professor from Taiwan University particularly insists on the fact that we must systematically add this information, and it is present in Hillier's book.
#
# There you have it, we can now rewrite our complete model, including the <b>nomenclature</b> of our sets, below the model.
#
# $$
# Max (R) = \sum_{j=1}^{4} p_{j}.x_{j}
# $$
# $$
# S.T
# $$
#
# $$
# \sum_{j=1}^{4} a_{ij}.x_{j} <= b_{i} \thinspace\thinspace\thinspace for \thinspace i = 1,2,3
# $$
#
# $$
# Where
# $$
#
# $$
#  x_{j} = production \thinspace level \thinspace for \thinspace product \thinspace PO_{j}
# $$
# $$
#  p_{j} = unit \thinspace profit \thinspace for \thinspace product \thinspace PO_{j}
# $$
# $$
#  a_{ij} = production \thinspace time \thinspace on \thinspace machine \thinspace i \thinspace per \thinspace unit \thinspace of \thinspace product \thinspace PO_{j}
# $$
# $$
#  b_{i} = production \thinspace time \thinspace available \thinspace per \thinspace week \thinspace on \thinspace machine \thinspace i
# $$
#
# Note: I copied the model from Hillier's book, we can see that there is a strangeness in the nomenclature in the book (b is indexed by i in the nomenclature, and by j in the constraint), which is not exactly the
# same as in the model, we will check, but the logic is there, I corrected it and put an i

# %% [markdown]
# ## 4.3 Solution using Python Pulp
#
# Now that we have our mathematical model ready, which we can even call a 'generic model', the second part is to find the solution using a Python solver.
# There are of course several, but Python Pulp is recognized as a famous and easy-to-access linear modeler.
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>
#
# So we have 2 elements, which we are now used to:
# - Our data <b>instance</b> which is our informative table from the beginning.
# - Our generic <b>mathematical model</b> , which we modeled by deduction.
#
# Our Python Pulp code must therefore be created in two steps: programming the instance, then programming the mathematical model, and must of course respect the elements to the letter, the nomenclature, and the names given to the sets, everything must be strictly identical, including the indentation.
#
# ## Step 1
# We enter our instance into our Python Pulp optimization program

# %%
# -----------------------------------
# STEP 1- We program the Data - which we can also call the Instance
# -----------------------------------
# We retrieve the data from the information table, in order to create an instance of data!
# Our products
X = [ 'P1' , 'P2' , 'P3' , 'P4' ]
# Their respective profits expressed in Dollars
P = { 'P1' : 26 , 'P2' : 35 , 'P3' : 25 , 'P4' : 37 }
# Production time available per machine for a week expressed in hours, it is a vector
B = [ 28 , 34 , 21 ]
# Matrix of production times per machine per product AOj, expressed in hours
A = [
[ 1.7 , 2.1 , 1.4 , 2.4 ],
[ 1.1 , 2.5 , 1.7 , 2.6 ],
[ 1.6 , 1.3 , 1.6 , 0.8 ]
]

# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )

# -----------------------------------
# Creation of Decision Variables
# -----------------------------------
# We stipulate that these are integer variables, normal, since they are non separable products
x = LpVariable . dicts ( "products" , X , lowBound = 0 , cat = 'Integer' )

# %% [markdown]
# ## Step 2
# We enter our mathematical model into our Python Pulp optimization program
# First comes the maximization objective function :
#
# $$
# Max (R) = \sum_{j=1}^{4} p_{j}.x_{j}
# $$

# %%
# -----------------------------------
# Objective function
# -----------------------------------
model += lpSum ([ P [ j ] * x [ j ] for j in X ]), "MAXIMIZE_PROFIT_R_FUNCTION"

# -----------------------------------
# Explanation
# -----------------------------------
# The previous line recreated dynamically:
# Max(R) = 26*PO1 + 35*P02 + 25*P03 + 37*P04
# using iterations, you have to visualize it in your head. It is the equivalent of our mathematical model
# and its summation symbol.

# %% [markdown]
# Then, it's a little more difficult for the constraints, because we're going to use the expression aij and therefore use and iterate on the matrix A that we defined during step 1. We're also going to use the vector B
# of maximum production times.
#
# $$
# \sum_{j=1}^{4} a_{ij}.x_{j} <= b_{i} \thinspace\thinspace\thinspace for \thinspace i = 1,2,3
# $$
#
# But we will first introduce our instance of data into this portion of the mathematical constraint model by hand, in order to understand what we will do next with the solver. If we place our instance into this
# mathematical model, by hand, we obtain:

# %%
# 1.7 * PO1 + 2.1 * P02 + 1.4 * P03, 2.4 * P04 <= 28
# 1.1 * PO1 + 2.5 * PO2 + 1.7 * PO3 + 2.6 * PO4 <= 34
# 1.6 * P01 + 1.3 * P02 + 1.6 * PO3 + 0.8 * PO4 <= 21

# %% [markdown]
# Now that we have a good understanding of what the constraints that the Python solver expects look like, we need to write the correct syntax of the model, in the Python Pulp solver.
#
# Since <b>we are no longer beginners</b>, we are obviously <b>not going to rewrite the constraints with hard values</b>, we are writing <b>the mathematical model, which will automatically iterate on the data</b>, which could be enormous in the future, if necessary (it's practical, when using databases).

# %%
# -----------------------------------
# Constraints
# -----------------------------------
for i , m in enumerate ( B ): # For each line i of minimum production time
    model += lpSum ( [ A [ i ][ idx ] * x [ j ] for idx , j in enumerate ( X ) ]) <= B [ i ] # For each decision variable, specify the machine working time per product

# -----------------------------------
# Explanation
# -----------------------------------
# The Python enumerate function allows you to retrieve the index and value of an array by iterating.
# It is used to recreate the mathematical model
# It is written as follows: for INDEX,VALUE in ENUMERATE(MY ARRAY)

# -----------------------------------
# Explanation 2
# -----------------------------------
# This constraint programming seems impressive, but in reality, it only iterates on our matrix A, and on each of
# its lines, as in the mathematical model. It only dynamically recreates the constraints that we wrote
# in hard in the part a little before.
# We check by printing the model that we find the same constraints, yes, that's the case!
print ( model )
# Out:
# Problem:
# MAXIMIZE
# 26*products_P1 + 35*products_P2 + 25*products_P3 + 37*products_P4 + 0
# SUBJECT TO
# _C1: 1.7 products_P1 + 2.1 products_P2 + 1.4 products_P3 + 2.4 products_P4
#  <= 28
#
# _C2: 1.1 products_P1 + 2.5 products_P2 + 1.7 products_P3 + 2.6 products_P4
#  <= 34
#
# _C3: 1.6 products_P1 + 1.3 products_P2 + 1.6 products_P3 + 0.8 products_P4
#  <= 21
#
# VARIABLES
# 0 <= products_P1 Integer
# 0 <= products_P2 Integer
# 0 <= products_P3 Integer
# 0 <= products_P4 Integer

# %% [markdown]
# ## 4.D Comparing the Hillier's book Lingo solver solution to the Python Pulp one.
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>
#
# So, let's now compare the solution found by Python Pulp to the Hillier's book one.
# Hillier used the LINGO solver, we are currently using the Python Pulp solver .

# %%
# -----------------------------------
# Solution
# ----------- ------------------------
model.solve ()

# We print the variables that have their values optimized
for v in model . variables ():
    print( v . name , "=" , v . varValue )

# The value of the optimized objective function is printed to the screen 
print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# products_P1 = 0.0
# products_P2 = 10.0
# products_P3 = 5.0
# products_P4 = 0.0
# Maximized total profit =  475.0

# %% [markdown]
# <b>HEY ! Yes, Solution is the same than the Hillier's book LINGO solver one ! Looks good, bro !</b>
#
# <div style="text-align:center">
# <img src="img/thumbs-up.jpg" width="100">
# </div>

# %% [markdown]
# # <b>5.  Getting Familiar with an objective function including a Σ and a cost subtraction. </b>
#
# ## 5.1 Presentation of the problem in a table
# Now that we have confirmed our optimization below in chapter 4, and confirmed the solution is the same than in the Hillier's book, let's add a fixed cost per produced product, and see how it impacts our mathematical model and our Python Pulp programmation.
#
# So, first : Our instance is modified like this :

# %% [markdown]
# <div style="text-align:center">
# <img src="img/hillier-2.png" />
# </div>

# %% [markdown]
# ## 5.2 Mathematical modeling
#
# We can obviously introduce a new set called C , for "costs",and we index it by j, taking care about the 4 columns.
# Like the Profit vector in chapter 4, We'll consider it as a vector.
# We make sure this costs adding technic is good by reading the well known AMP doc.
#
# So, let's place it in our model.
#
# $$
# Max (R) = \sum_{j=1}^{4} (p_{j}-c_{j}).x_{j}
# $$
# $$
# S.T
# $$
#
# $$
# \sum_{j=1}^{4} a_{ij}.x_{j} <= b_{i} \thinspace\thinspace\thinspace for \thinspace i = 1,2,3
# $$
#
# $$
# Where
# $$
#
# $$
#  x_{j} = production \thinspace level \thinspace for \thinspace product \thinspace PO_{j}
# $$
# $$
#  p_{j} = unit \thinspace profit \thinspace for \thinspace product \thinspace PO_{j}
# $$
# $$
#  a_{ij} = production \thinspace time \thinspace on \thinspace machine \thinspace i \thinspace per \thinspace unit \thinspace of \thinspace product \thinspace PO_{j}
# $$
# $$
#  b_{i} = production \thinspace time \thinspace available \thinspace per \thinspace week \thinspace on \thinspace machine \thinspace i
# $$
# $$
#  c_{j} = cost \thinspace per \thinspace produced \thinspace product\thinspace
# $$

# %% [markdown]
# # 5.3 Python Pulp Solution
#
#
# Let's first enter our new C set in our data instance.

# %%
# Costs 
C = { 'P1' : 0.2 , 'P2' : 0.3 , 'P3' : 0.2 , 'P4' : 0.3 }

# %% [markdown]
# Our math model objective function is now different, so let's modify the math model correctly, also inside of the Python Pulp code :.
# $$
# Max (R) = \sum_{j=1}^{4} (p_{j}-c_{j}).x_{j}
# $$

# %%
# -----------------------------------
# Objective function
# -----------------------------------
model += lpSum ([ (P [ j ] - C [ j ]) * x [ j ] for j in X ]), "MAXIMIZE_PROFIT_R_FUNCTION"

# %% [markdown]
# ## Checking solution :
#
# Let's rewrite the whole code without previous explanations.
# Solution substracted costs and took it in consideration while resolving the linear optimization. We got less profit than before.

# %%
from pulp import *
# Instance
X = [ 'P1' , 'P2' , 'P3' , 'P4' ]
P = { 'P1' : 26 , 'P2' : 35 , 'P3' : 25 , 'P4' : 37 }
C = { 'P1' : 0.2 , 'P2' : 0.3 , 'P3' : 0.2 , 'P4' : 0.3 }
B = [ 28 , 34 , 21 ]
A = [
[ 1.7 , 2.1 , 1.4 , 2.4 ],
[ 1.1 , 2.5 , 1.7 , 2.6 ],
[ 1.6 , 1.3 , 1.6 , 0.8 ]
]

# Params
model = LpProblem ( 'Problem' , LpMaximize )
x = LpVariable . dicts ( "products" , X , lowBound = 0 , cat = 'Integer' )

# Math model
model += lpSum ([ (P [ j ] - C [ j ]) * x [ j ] for j in X ]), "MAXIMIZE_PROFIT_R_FUNCTION"

for i , m in enumerate ( B ): 
    model += lpSum ( [ A [ i ][ idx ] * x [ j ] for idx , j in enumerate ( X ) ]) <= B [ i ] 

# Solution
model.solve ()

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# products_P1 = 0.0
# products_P2 = 10.0
# products_P3 = 5.0
# products_P4 = 0.0
# Maximized total profit =  471.0

# %% [markdown]
# # <b> 6. Getting familiar with double summation writing ΣΣ and Xij decisions variables</b>

# %% [markdown]
# Let's take this famous PowerCo transportation example from http://www.inf.u-szeged.hu/~london/Linprog/linprog7.pdf , and from - ( - still unknown book - , This example is based on Aarvik and Randolph (1975).
# And Let's focus on the double summation only and why it exists , then, we'll find the solution using Python Pulp.
# Let's understand how Xij decisions variables works too, cause if we look at chapter 4, we see that we deal with Xj decisions variables, with only one indice, but now, Xij has 2 indices, let's see why.

# %% [markdown]
# ##  Aarvik and Randolph (1975) transportation problem
#
#
# <div style="text-align:center">
# <img src="img/electricityplant.jpg" width="500">
# </div>
#
#
# Powerco has three electric power plants that supply the needs of four cities.
# Each power plant can supply the following numbers of kilowatt-hours (kwh) of electricity:
# - plant 1 — 35 million
# - plant 2 — 50 million
# - plant 3 — 40 million
#
# The peak power demands in these cities, which occur at the same time (2 P.M.), are as follows (in kwh):
# - city 1—45 million
# - city 2—20 million
# - city 3—30 million
# - city 4—30 million
#
# The costs of sending 1 million kwh of electricity from plant to city depend on the distance the elec-
# tricity must travel. Formulate an LP to minimize the cost of meeting each city’s peak
# power demand.
#
# ## 6.1 Our instance table :
#
# <div style="text-align:center">
# <img src="img/powerco.png">
# </div>

# %% [markdown]
# ## 6.2 Mathematical modeling.
#
# There is the <b>objective function instance</b> to be minimized :
# ![xandj.png](attachment:xandj.png)
#
# We can see that the decision variables are present on several lines, which implies an Xij type notation because we iterate over the lines and columns to find them. So when in chapter 4, the decision variables are on a single line and we therefore had an Xj type notation which only iterated over the columns.
# In fact, decisions variables are an <b>association</b> of 2 "components".
# In other words, instead of having a single line of decision variables, we have an entire table, hence the need to index by i and j at the same time.
#
#
# There is the <b>Math model objective function</b> :
#
# $$
# Min \sum_{i=1}^{i=m} \sum_{j=1}^{j=n} c_{ij}.x_{ij}
# $$
#
# we also see that the costs are indexed by i for the rows and j for the columns. Now why are there 2 summation symbols?
# It's because number of lines is not equal to the number of rows, and for i = 1, 2, 3 (m=number of lines)and j = 1, 2, 3, 4(n=number of rows)

# %% [markdown]
# Now, here are the constraints written in hard :
#
# <div style="text-align:center">
# <img src="img/hardcodedconstraints.png" width="500"/>
# </div>
#
# Then, converted to a math model :
#
#
# $$
# \sum_{j=1}^{n} x_{ij} <= s_{i} \thinspace\thinspace\thinspace for \thinspace i = 1,2,3,m
# $$
#
# $$
# \sum_{j=1}^{m} x_{ij} <= d_{j} \thinspace\thinspace\thinspace for \thinspace j = 1,2,3,4,n
# $$
#
# $$
# x_{ij} \ge 0 \thinspace (i = 1,2,3...m; j = 1,2,...n)
# $$
#
# $$
# Where
# $$
#
# $$
#  x_{ij} = number \thinspace of \thinspace (million) \thinspace kwh \thinspace produced \thinspace at \thinspace plant \thinspace i \thinspace and \thinspace sent \thinspace to \thinspace city \thinspace j
# $$
#
# $$
#  c_{ij} = cost \thinspace of \thinspace (million) \thinspace kwh \thinspace produced \thinspace at \thinspace plant \thinspace i \thinspace and \thinspace sent \thinspace to \thinspace city \thinspace j
# $$
#
# $$
#  s_{i} = supply \thinspace available \thinspace per \thinspace plant
# $$
#
# $$
#  d_{j} = demand \thinspace per \thinspace city
# $$
#
# $$
#  p_{i} = plant_{i}
# $$
#
# $$
#  ct_{j} = city_{j}
# $$

# %% [markdown]
# ## 6.3 Solution using Python Pulp.
#
# Let's enter our instance.

# %%
# -----------------------------------
# Instance
# -----------------------------------

# I respect the math nomenclature sets names

# plants
p = ['1','2','3']
# cities
ct = ['A','B','C','D']
# costs
c = [  
            [8,    6,   10,  9],        # 1   CITY
            [9,    12,  13,  7],        # 2
            [14,   9,   16,  5],        # 3

]
# supply per plant
s = { '1' : 35 , '2' : 40 , '3' : 50 }
# demand per city
# d = { 'A' : 45 , 'B' : 20 , 'C' : 30 , 'D' : 30}
d = [45,20,30,30]

# -----------------------------------
# Type of problem
# -----------------------------------
Problem = LpProblem('optimisation_transport',LpMinimize)

# %% [markdown]
# Now, we have to re-create the Objective function math model.
#
# $$
# Min \sum_{i=1}^{i=m} \sum_{j=1}^{j=n} c_{ij}.x_{ij}
# $$
#
# It should automatically recreate the following hard coded data :
#
# <div style="text-align:center">
# <img src="img/xandj.png" width="500"/>
# </div>

# %%
# Create a list of all possibilities
Routes = [(w, b) for w in p  for b in ct]

# Create decisions variables list
x = LpVariable.dicts("Route", (p , ct), 0, None, LpInteger)

# Create a cost directory
cost = makeDict([p,ct], c, 0)

# Objective function
Problem += lpSum([cost[w][b]  * x[w][b]  for (w, b) in Routes])

# Let's print model, to make sure our objective function is ok.
print(Problem)
# Out:
# optimisation_transport:
# MINIMIZE
# 8*Route_1_A + 6*Route_1_B + 10*Route_1_C + 9*Route_1_D + 9*Route_2_A + 12*Route_2_B + 13*Route_2_C + 7*Route_2_D + 14*Route_3_A + 9*Route_3_B + 16*Route_3_C + 5*Route_3_D + 0
# VARIABLES
# 0 <= Route_1_A Integer
# 0 <= Route_1_B Integer
# 0 <= Route_1_C Integer
# 0 <= Route_1_D Integer
# 0 <= Route_2_A Integer
# 0 <= Route_2_B Integer
# 0 <= Route_2_C Integer
# 0 <= Route_2_D Integer
# 0 <= Route_3_A Integer
# 0 <= Route_3_B Integer
# 0 <= Route_3_C Integer
# 0 <= Route_3_D Integer

# %% [markdown]
# And now let's recreate constraints.
#
# $$
# \sum_{j=1}^{n} x_{ij} <= s_{i} \thinspace\thinspace\thinspace for \thinspace i = 1,2,3,m
# $$
#
# $$
# \sum_{j=1}^{m} x_{ij} <= d_{j} \thinspace\thinspace\thinspace for \thinspace j = 1,2,3,4,n
# $$
#
# Mathematical model has to be able to recreate to theses hard coded constraints, when feeded by datas :
# <div style="text-align:center">
# <img src="img/hardcodedconstraints.png" width="500"/>
# </div>
#
# Ok, first, I am going to hard code constraints, then we'll try to iterate instead, in a second step.
#
# We can access decisions variables using their indexes.

# %%
# Supply constraints
Problem += x["1"]["A"] + x["1"]["B"] + x["1"]["C"] + x["1"]["D"] >=35
Problem += x["2"]["A"] + x["2"]["B"] + x["2"]["C"] + x["2"]["D"] >=50
Problem += x["3"]["A"] + x["3"]["B"] + x["3"]["C"] + x["3"]["D"] >=40

# Demand constraints
Problem += x["1"]["A"] + x["2"]["A"] + x["3"]["A"]  >=45
Problem += x["1"]["B"] + x["2"]["B"] + x["3"]["B"]  >=20
Problem += x["1"]["C"] + x["2"]["C"] + x["3"]["C"]  >=30
Problem += x["1"]["D"] + x["2"]["D"] + x["3"]["D"]  >=30


Problem.solve() 

print('Status:', LpStatus[Problem.status])
print('Total minimized cost = ', value(Problem.objective))
 
for i in Problem.variables():
    if i.varValue > 0:
        print('Route :',i.name, '=', i.varValue)
# Out:
# Status: Optimal
# Total minimized cost =  1020.0
# Route : Route_1_B = 10.0
# Route : Route_1_C = 25.0
# Route : Route_2_A = 45.0
# Route : Route_2_C = 5.0
# Route : Route_3_B = 10.0
# Route : Route_3_D = 30.0

# %% [markdown]
# # Comparing solution to the Book's one
#
# Book screen copy :
# <div style="text-align:center">
# <img src="img/solution1.png" width="500"/>
# </div>
#
# Yes, It's the same than the Excel one , looks good, bro.
# <div style="text-align:center">
# <img src="img/thumbs-up.jpg" width="100">
# </div>

# %% [markdown]
# ## Now, let's iterate over datas instead of hard coding constraints, We code the mathematical model directly
#
# First, let's redo this Supply constraint:
#
# $$
# \sum_{j=1}^{ct} x_{ij} <= s_{i} \thinspace\thinspace\thinspace for \thinspace i = 1,2,3,m
# $$
#
# PLease notice that I stay similar to the math model, as much as possible !

# %%
# -----------------------------------
# Constraints
# -----------------------------------

# Supply constraint
for i in p : # For each plant
    Problem += lpSum ( [ x [ i ][ j ] for j in ct ]) >= s[i]

# Model will then automatically create theses lines
# No need to hard code it any more, less pain, if you see what I mean ...
# Problem += x["1"]["A"] + x["1"]["B"] + x["1"]["C"] + x["1"]["D"] >=35
# Problem += x["2"]["A"] + x["2"]["B"] + x["2"]["C"] + x["2"]["D"] >=50
# Problem += x["3"]["A"] + x["3"]["B"] + x["3"]["C"] + x["3"]["D"] >=40

# %% [markdown]
# And now, let's program this last demand constraint :
#
# $$
# \sum_{j=1}^{m} x_{ij} <= d_{j} \thinspace\thinspace\thinspace for \thinspace j = 1,2,3,4,n
# $$

# %%
# Demand constraint
for idx,m in enumerate (ct) : # For each city
    Problem += lpSum ( [ x [ i ][ m ] for i in p ]) >= d[idx]

# Model will then automatically create theses lines
# Problem += x["1"]["A"] + x["2"]["A"] + x["3"]["A"]  >=45
# Problem += x["1"]["B"] + x["2"]["B"] + x["3"]["B"]  >=20
# Problem += x["1"]["C"] + x["2"]["C"] + x["3"]["C"]  >=30
# Problem += x["1"]["D"] + x["2"]["D"] + x["3"]["D"]  >=30

# %% [markdown]
# Ok, let's rewrite the whole code without comments , and check if solution is still OK.

# %%
# -----------------------------------
# Instance
# -----------------------------------

# plants
p = ['1','2','3']
# cities
ct = ['A','B','C','D']
# costs
c = [  
        [8,    6,   10,  9],        # 1   CITY
        [9,    12,  13,  7],        # 2
        [14,   9,   16,  5],        # 3
]
# supply per plant
s = { '1' : 35 , '2' : 50 , '3' : 40 }
# demand per city
# d = { 'A' : 45 , 'B' : 20 , 'C' : 30 , 'D' : 30}
d = [45,20,30,30] # We'll see later why I need to express it like that, and if we can do better.

# -----------------------------------
# Type of problem
# -----------------------------------
Problem = LpProblem('optimisation_transport',LpMinimize)

# -----------------------------------
# MATHEMATICAL MODEL
# -----------------------------------

# -----------------------------------
# Objective
# -----------------------------------

# Create a list of all possibilities
Routes = [(w, b) for w in p  for b in ct]

# Create decisions variables list
x = LpVariable.dicts("Route", (p , ct), 0, None, LpInteger)

# Create a cost directory
cost = makeDict([p,ct], c, 0)

# Objective function
Problem += lpSum([cost[w][b]  * x[w][b]  for (w, b) in Routes])


# -----------------------------------
# Constraints
# -----------------------------------

# Supply constraint
for i in p : # For each plant
    Problem += lpSum ( [ x [ i ][ j ] for j in ct ]) >= s[i]

# Demand constraint
for idx,m in enumerate (ct) : # For each city
    Problem += lpSum ( [ x [ i ][ m ] for i in p ]) >= d[idx]

# -----------------------------------
# Solution
# -----------------------------------

Problem.solve() 

print('Statut:', LpStatus[Problem.status])
print('Total minimized cost = ', value(Problem.objective))
 
for i in Problem.variables():
    if i.varValue > 0:
        print('Route :',i.name, '=', i.varValue)
# Out:
# Statut: Optimal
# Total minimized cost =  1020.0
# Route : Route_1_B = 10.0
# Route : Route_1_C = 25.0
# Route : Route_2_A = 45.0
# Route : Route_2_C = 5.0
# Route : Route_3_B = 10.0
# Route : Route_3_D = 30.0

# %% [markdown]
# Solution is still the same than in the book.

# %% [markdown]
# # <b>7. Getting familiar with logical/conditional constraints</b>

# %% [markdown]
# ## 7.1 Best available ressources on the internet and table summaries
#
# <b>Introduction</b>
# There are 2 type of logical constraints, firsts ones are somewhat"easy" to understand (Associations,Exclusions,At least... ), but the second part, called "BIG M" methods is hard to understand and to program, and prone to errors (In my case, for now...).
# In both cases, summary tables produced by specialists are rencently appearing on the Internet.As this topic is quite broad, it is beyond the scope of this notebook and requires a dedicated notebook.
#
# <div style="text-align:center">
# <img src="img/hku.png" width="300">
# </div>
# Pan Li - Chinese university of Hong Kong (Best doc I've found for now):
#
# - https://www.math.cuhk.edu.hk/course_builder/1415/math3220/L2%20(without%20solution).pdf
#
# <div style="text-align:center">
# <img src="img/MIT-Logo-Histoire.jpg" width="300">
# </div>
#
# M.I.T courseware great logical constraints and BigM Methods course:
# - https://ocw.mit.edu/courses/15-053-optimization-methods-in-management-science-spring-2013/5b3af480d3aacc8c345c9e0ecfdd4ba4_MIT15_053S13_tut09.pdf
#
# - https://ocw.mit.edu/courses/15-053-optimization-methods-in-management-science-spring-2013/resources/mit15_053s13_lec11/
#
# M.I.T complete course :
# - https://ocw.mit.edu/courses/15-053-optimization-methods-in-management-science-spring-2013/pages/lecture-notes/
#
#
# <div style="text-align:center">
# <img src="img/Artboard-3-copy-2-1.png" width="300">
# </div>
#
# Newest AIMMS course, including the famous "Integer tricks" tutorial :
# - https://documentation.aimms.com/_downloads/AIMMS_modeling.pdf
#
# Alex Fleischer doc :
# - https://www.linkedin.com/pulse/making-optimization-simple-python-alex-fleischer/
#
#
# Dell and Brown formulettes :
# - https://pubsonline.informs.org/doi/pdf/10.1287/ited.7.2.153
#
# Maths.cuhk
# - https://www.math.cuhk.edu.hk/course_builder/1415/math3220/L2%20(without%20solution).pdf
#
# <div style="text-align:center">
# <img src="img/keen.png" width="300">
# </div>
#
#
# Ben Alex Keen Phd tutorial :
# - https://benalexkeen.com/linear-programming-with-python-and-pulp-part-6/
#
# StackExchange case :
# - https://math.stackexchange.com/questions/1851140/binary-integer-variables-in-linear-programming
#
#
#
# ## Table summary :
#
# Logical conditions :
#
# - https://desmond-ong.github.io/stats-notes/logical-constraints.html
#
# Pan Li - Chinese university of Hong Kong (Best doc):
# - https://www.math.cuhk.edu.hk/course_builder/1415/math3220/L2%20(without%20solution).pdf
#
# Big M If Then table :
#
# - https://laurentlessard.com/teaching/cs524/slides/20%20-%20logic%20constraints%20and%20integer%20variables.pdf

# %% [markdown]
# ## 7.2.1 Presentation of the capital budgeting problem
#
# Let's examine this example exposed in " Optimizations modeling with spreadsheets" by Kenneth R. Baker.<br>
#
# <div style="text-align:center">
# <img src="img/cpb.jpg" width="500"/>
# </div>
#
#
# Division A of the Newton Corporation has been allocated $40 million for capital projects this
# year. Managers in Division A have examined various possibilities and have proposed five pro-
# jects for the capital budgeting committee to consider. The projects cover a variety of activities
# and functional areas, and there is just one of each type.<br>
# Each project has an estimated net present value (NPV), and each requires a capital expenditure,
# which must come out of the budget for capital projects.
# The following table summarizes the possibilities, as they have been provided to the committee, with all figures in millions of dollars.
#
#  <table>
#   <tr>
#     <th><b>Project</b></th>
#     <th>P1</th>
#     <th>P2</th>
#     <th>P3</th>
#     <th>P4</th>
#     <th>P5</th>
#   </tr>
#   <tr>
#     <td>NPV</td>
#     <td>2.0</td>
#     <td>3.6</td>
#     <td>3.2</td>
#     <td>1.6</td>
#     <td>2.8</td>
#   </tr>
#   <tr>
#     <td>Expenditure</td>
#     <td>12</td>
#     <td>24</td>
#     <td>20</td>
#     <td>8</td>
#     <td>16</td>
#   </tr>
# </table>
#
# The committee would like to maximize the total NPV from projects selected, subject to a 40
# millions dollars limit on capital expenditures. This 40 millions dollars constraint makes it impossible to under-
# take all five projects; a subset of the five must be selected.

# %% [markdown]
# ## 7.2.2 Mathematical modeling
#
# We are now used to model a math model from an instance, so, unlike the book, I do write the maths model directly, retrieving sets, and including the mandatory nomenclature.
#
# $$
# Max (Z) = \sum_{j=1}^{5} n_{j}.x_{j}
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{e} e_{j}.x_{j} <= 40
# $$
# $$
# x_{j} \in \{0,1\}
# $$
#
# $$
# where
# $$
#
# $$
#  x_{j} = project \thinspace selection
# $$
# $$
#  n_{j} = NPV \thinspace per \thinspace project \thinspace Pj
# $$
# $$
#  e_{j} = expenditure \thinspace per \thinspace \thinspace project \thinspace Pj
# $$
#
# <br>
# We notice that decisions variables are now binary, and are used to select a j project  or not.
# We notice that there is no i indice in this model.

# %% [markdown]
# ## 7.2.3 Solution using Python Pulp and Book's Excel solution comparison
#
#
# As always, first comes the Instance, with datas, then the math model is written in Python.
# Notice that sets names are stricly the same than in the math model, so it's easy to come from one to the other.

# %%
# Instance
X = [ 'P1' , 'P2' , 'P3' , 'P4','P5' ]
n = { 'P1' : 2.0 , 'P2' : 3.6 , 'P3' : 3.2 , 'P4' : 1.6, 'P5':2.8 }
e = { 'P1' : 12 , 'P2' : 24 , 'P3' : 20 , 'P4' : 8, 'P5':16 }


# Params
model = LpProblem ( 'Problem' , LpMaximize )
x = LpVariable . dicts ( "project" , X , lowBound = 0 , cat= 'Binary' )

# Math model
# Objective
model += lpSum ([ n [ j ] * x [ j ] for j in X ]), "MAXIMIZE_Z_FUNCTION"

# Constraints
model += lpSum ( [ e [ j ] * x [ j ] for j in X ]) <= 40

# Solution
model.solve ()

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Total NPV = " , value ( model.objective ) )
# Out:
# project_P1 = 1.0
# project_P2 = 0.0
# project_P3 = 1.0
# project_P4 = 1.0
# project_P5 = 0.0
# Total NPV =  6.800000000000001

# %% [markdown]
# We see that the book's Excel solution is the same than the one we find using Python Pulp, here is a screen cap of the book :
# <div style="text-align:center">
# <img src="img/chapter7solution.png">
# </div>
#
# Looks good, bro !
# <div style="text-align:center">
# <img src="img/thumbs-up.jpg" width="100">
# </div>

# %% [markdown]
# ## 7.2.4 Mathematical modeling of conditional constraints.
#
# <h3><b>Association:</b></h3>
# Regarding the previous problem, let's imagine an additional association constraint, if project 1 is chosen, then project 2 must be chosen.
# Let's add this inside of the math model :
# $$
#  x_{2} >= x_{1}
# $$
#
# Source :
# https://or.stackexchange.com/questions/33/in-an-integer-program-how-i-can-force-a-binary-variable-to-equal-1-if-some-cond
#
# And, now, let's modify the Python Pulp program accordingly :

# %%
# Instance
X = [ 'P1' , 'P2' , 'P3' , 'P4','P5' ]
n = { 'P1' : 2.0 , 'P2' : 3.6 , 'P3' : 3.2 , 'P4' : 1.6, 'P5':2.8 }
e = { 'P1' : 12 , 'P2' : 24 , 'P3' : 20 , 'P4' : 8, 'P5':16 }


# Params
model = LpProblem ( 'Problem' , LpMaximize )
x = LpVariable . dicts ( "project" , X , lowBound = 0 , cat= 'Binary' )

# Math model
# Objective
model += lpSum ([ n [ j ] * x [ j ] for j in X ]), "MAXIMIZE_Z_FUNCTION"

# Constraints
model += lpSum ( [ e [ j ] * x [ j ] for j in X ]) <= 40

model +=  x['P2'] >= x['P1']

# Solution
model.solve ()

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Total NPV = " , value ( model.objective ) )
# Out:
# project_P1 = 0.0
# project_P2 = 1.0
# project_P3 = 0.0
# project_P4 = 0.0
# project_P5 = 1.0
# Total NPV =  6.4

# %% [markdown]
# <h3><b>Exclusion</b></h3>

# %% [markdown]
# Let's now imagine an additional exclusion constraint, if project 1 is chosen, then project 2 must  not be chosen.<br>
# Let's add this inside of the math model :
#
# $$
# x_{1} + x_{2} <= 1
# $$

# %%
# Instance
X = [ 'P1' , 'P2' , 'P3' , 'P4','P5' ]
n = { 'P1' : 2.0 , 'P2' : 3.6 , 'P3' : 3.2 , 'P4' : 1.6, 'P5':2.8 }
e = { 'P1' : 12 , 'P2' : 24 , 'P3' : 20 , 'P4' : 8, 'P5':16 }


# Params
model = LpProblem ( 'Problem' , LpMaximize )
x = LpVariable . dicts ( "project" , X , lowBound = 0 , cat= 'Binary' )

# Math model
# Objective
model += lpSum ([ n [ j ] * x [ j ] for j in X ]), "MAXIMIZE_Z_FUNCTION"

# Constraints
model += lpSum ( [ e [ j ] * x [ j ] for j in X ]) <= 40

model +=  x['P1'] + x['P2'] <= 1

# Solution
model.solve ()

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Total NPV = " , value ( model.objective ) )
# Out:
# project_P1 = 1.0
# project_P2 = 0.0
# project_P3 = 1.0
# project_P4 = 1.0
# project_P5 = 0.0
# Total NPV =  6.800000000000001

# %% [markdown]
# <h3><b>At least</b></h3>
#
# Suppose I have to pick at least 4 projects:
#
# Let's add this inside of the math model :
#
# $$
# x_{1} + x_{2} + x_{3} + x_{4} + x_{5}  >= 4
# $$
#
# Look how funny is the solution... He can't pick 4,because constraints are overwhelming.

# %%
# Instance
X = [ 'P1' , 'P2' , 'P3' , 'P4','P5' ]
n = { 'P1' : 2.0 , 'P2' : 3.6 , 'P3' : 3.2 , 'P4' : 1.6, 'P5':2.8 }
e = { 'P1' : 12 , 'P2' : 24 , 'P3' : 20 , 'P4' : 8, 'P5':16 }


# Params
model = LpProblem ( 'Problem' , LpMaximize )
x = LpVariable . dicts ( "project" , X , lowBound = 0 , cat= 'Binary' )

# Math model
# Objective
model += lpSum ([ n [ j ] * x [ j ] for j in X ]), "MAXIMIZE_Z_FUNCTION"

# Constraints
model += lpSum ( [ e [ j ] * x [ j ] for j in X ]) <= 40

model +=  x['P1'] + x['P2'] + x['P3'] + x['P4'] + x['P5'] >= 4

# Solution
model.solve ()

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Total NPV = " , value ( model.objective ) )

print('Status:', LpStatus[Problem.status])
# Out:
# project_P1 = 1.0
# project_P2 = 0.0
# project_P3 = 0.2
# project_P4 = 1.0
# project_P5 = 1.0
# Total NPV =  7.04
# Status: Optimal

# %% [markdown]
# <h3><b>Prerequisite</b></h3>
#
# Credits : https://desmond-ong.github.io/stats-notes/logical-constraints.html
#
# Let’s say that X1 is whether I decide to buy a new house, and X2 is whether I decide to renovate the new house. We restrict both X1, X2 to be either 0 or 1. Obviously, I need to purchase the house before I can renovate it, so X1 is a pre-requisite for X2.
#
# Using logic, I can write that:
#
# - if I choose X2,then I must choose X1 as well.
#
# This logical constraint can be formalised as the following integer-valued constraint:
#
# $$
#  X_{1}−X_{2}≥0
# $$

# %% [markdown]
# ## <b>7.3 IF-THEN Fixed costs example</b>
#
# Let's consider my 2.1 chapter example and let's add a conditional 5000$ fixed cost, as long as more than 0 A type of cars get produced .
#
# <b>If A > 0 Then Cost = 5000 $</b>
#
# <div style="text-align:center">
# <img src="img/000171013_896x598_c.jpg" width="500"/>
# </div>
#
# Here is the updated table <b> instance </b>
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#    <tr>
#     <td> > 0 produced car cost </td>
#     <td>5000</td>
#     <td>0</td>
#   </tr>
#
# </table>
#
# The objective is still to maximize the main profit.
#
# Let's write down the <b>math model</b> real fast without the i indice:
#
# $$
# Max (Z) = \sum_{j=1}^{2} p_{j}.x_{j} - 5000y
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{k} k_{j}.x_{j} <= 5000
# $$
# $$
#  \sum_{j=1}^{z} z_{j}.x_{j} <= 6000
# $$
#
# $$
#  \begin{equation}
#   y =
#     \begin{cases}
#       0 & \text{for x1 = 0}\\
#
#
#       1 & \text{for x1 > 0}\\
#
#     \end{cases}
#   \end{equation}
# $$
#
# $$
# x \in  ℕ
# $$
#
# $$
# y \in \{0,1\}
# $$
#
# $$
# where
# $$
#
# $$
#  x_{j} = number \thinspace of \thinspace produced \thinspace cars
# $$
# $$
#  p_{j} = profit \thinspace  per \thinspace x_{j}  \thinspace car
# $$
# $$
#  k_{j} = needed \thinspace k \thinspace supply \thinspace per \thinspace x_{j}  \thinspace car
# $$
# $$
#  z_{j} = needed \thinspace z \thinspace supply \thinspace per \thinspace x_{j}  \thinspace car
# $$
# $$
#  y = Apply \thinspace conditional \thinspace cost \thinspace binary \thinspace variable
# $$
#
#
# ## Solution using Ibm Cplex internal IF THEN feature.
#
# <div style="text-align:center">
# <img src="img/IBM_CPLEX_0.png">
# </div>
#
# Let's first use CPLEX to program this conditional constraint, because that's easier. <br>
# <b>If A > 0 Then Cost = 5000 $</b>
# we can verify that more than 0 A cars have been produced<br>
# so the conditional cost gets substracted, and y is valued 1:

# %%
# -----------------------------------
# Import from CPLEX
# -------- ---------------------------
import cplex
import docplex.mp
from docplex.mp.model import Model

# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = Model(name='Problem', log_output=True)

# -----------------------------------
# Decision variables
# -----------------------------------
A = model.integer_var(name='A')
B = model.integer_var(name='B')
y = model.binary_var(name='y')

# -----------------------------------
# Z Objective function 
# -----------------------------------
model.maximize(20000 * A  + 18000 * B - 5000 * y )

# -----------------------------------
# Constraints
# -----------------------------------
model.add_constraint(20 * A + 18 * B <= 5000)
model.add_constraint(10 * A + 8 * B <= 6000)

# -----------------------------------
# Conditional Constraint
# -----------------------------------
model.add_constraint(model.if_then(A >= 1, y == 1))

# -----------------------------------
# Solution
# ----------- ------------------------
model.parameters.mip.display.set(0)
sol_model = model.solve()
model.print_solution()
# Out:
# Version identifier: 22.1.1.0 | 2023-02-09 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_MIP_Display                             0
# objective: 4995000
# status: OPTIMAL_SOLUTION(2)
#   A=7
#   B=270
#   y=1

# %% [markdown]
# Now, let's use Python Pulp to do the same thing.
#
# But wait, wait , wait, Isn't this tutorial focused on math modeling ? We just modeled without the i indice above, well, That's obviously not good, considering that the math model should avoid hard coded values, as much as possible.
# So let's try to correct the math model, and add the i index/indice, to do that, I have to consider my cars table instance as a Aij matrix, not as several parted lines. Why that? Because I want to reduce my math model, what if one day, I have 30 supply constraints lines , will I write down 30 lines in my model , hell no. Let's use this "magical" Aij notation, and reduce our model size:
#
# $$
# Max (Z) = \sum_{j=1}^{2} p_{j}.x_{j} - 5000y
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{2} a_{ij}.x_{j} <= s_{i} \thinspace for \thinspace i = 1,2
# $$
#
# $$
#  \begin{equation}
#   y =
#     \begin{cases}
#       0 & \text{for x1 = 0}\\
#
#
#       1 & \text{for x1 > 0}\\
#
#     \end{cases}
#   \end{equation}
# $$
#
# $$
# x \in  ℕ
# $$
#
# $$
# y \in \{0,1\}
# $$
#
# $$
# where
# $$
#
# $$
#  x_{j} = number \thinspace of \thinspace produced \thinspace cars
# $$
# $$
#  p_{j} = profit \thinspace  per \thinspace x_{j}  \thinspace car
# $$
# $$
#  a_{ij} = needed \thinspace supply \thinspace per  \thinspace car
# $$
# $$
#  s_{i} =  inventory \thinspace per \thinspace line
# $$
# $$
#  y = Apply \thinspace conditional \thinspace cost \thinspace binary \thinspace variable
# $$
#
#
#
# <i>Tip : Consider the math model as a machine or even a "monster" that is fed by an instance of datas. It is mandatory to mention each set in the nomenclature, otherwise you will lose the people with whom you are communicating.</i>
#
# ## Solution using Python Pulp using a first BIG M Method.
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>
#
# Ok, now, I am ready to use Python Pulp to solve this optimization problem . Unlike Cplex, Python Pulp does not have a IF THEN feature, therefore, I will have to use a BIG M Method to express the IF THEN binary constraint. The main guide for doing that is the Pan Li - Chinese university of Hong Kong doc:
# - https://www.math.cuhk.edu.hk/course_builder/1415/math3220/L2%20(without%20solution).pdf.
#
# Creating the main code, then adding the conditional variable using BigM in a second part :
#
# <b>First step : Creating the main Python Pulp code, as in Chapter 2.1, but using iterations</b>

# %%
# -----------------------------------
# Instance
# -----------------------------------
X = [ 'A' , 'B' ]
p = { 'A' : 20000 , 'B':18000}
a = [{ 'A' : 20 , 'B':18},
     { 'A' : 10 , 'B':8 }]
s = [5000,6000]

# -----------------------------------
# Type of problem
# -----------------------------------
model = LpProblem ( 'Problem' , LpMaximize )

# -----------------------------------
# Decisions variables
# -----------------------------------
x = LpVariable . dicts ( "car" , X , lowBound = 0 , cat = 'Integer' )

# -----------------------------------
# Math model
# -----------------------------------

# Objective function, stricly like Math model
model += lpSum ([ p [ j ] * x [ j ] for j in X ]), "MAXIMIZE_Z_FUNCTION"

# Constraints

# 1. Supply constraint
for i,valued in enumerate(s) : # For each supply lines , i is the indice, valued is the value
    model += lpSum ( [ a [ i ][ j ] * x [j] for j in X ]) <= s[i] # Stricly same as the math model

# -----------------------------------
# Solution
# -----------------------------------
model.solve ()

print('Status:', LpStatus[model.status])

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# Status: Optimal
# car_A = 7.0
# car_B = 270.0
# Maximized total profit =  5000000.0

# %% [markdown]
# <b>Step 2 : Adding conditional variable using BigM method</b>
#
# <b>If A > 0 Then Cost = 5000 $</b>
#
# Found at  : https://www.ibm.com/support/pages/difference-between-using-indicator-constraints-and-big-m-formulation
#
# This is still to be confirmed - <span style="color:red">Warning, I still have to review this fixed cost BigM Technic and compare it to several docs.</span>
#
# <div style="text-align:center">
# <img src="img/ibm-bigm.png" width="500">
# </div>

# %%
# -----------------------------------
# Instance
# -----------------------------------
X = [ 'A' , 'B' ]
p = { 'A' : 20000 , 'B':18000}
a = [{ 'A' : 20 , 'B':18},
     { 'A' : 10 , 'B':8 }]
s = [5000,6000]

# -----------------------------------
# Type of problem
# -----------------------------------
model = LpProblem ( 'Problem' , LpMaximize )

# -----------------------------------
# Decisions variables
# -----------------------------------
x = LpVariable . dicts ( "car" , X , lowBound = 0 , cat = 'Integer' )
y = LpVariable("y", 0, None, LpBinary) # Binary variable creation

# -----------------------------------
# Math model
# -----------------------------------

# Objective function, stricly like Math model, added cost substraction, triggered by the y variable
model += lpSum ([ p [ j ] * x [ j ] for j in X ] - 5000 * y), "MAXIMIZE_Z_FUNCTION"

# Constraints

# 1. Supply constraint
for i,valued in enumerate(s) : # For each supply lines , i is the indice, valued is the value
    model += lpSum ( [ a [ i ][ j ] * x [j] for j in X ]) <= s[i] # Stricly same as the math model

# 2. Conditional cost constraint

M = 100  # A BigM value, as large as possible

# if car x["A"] > 0 then  y = 1 is :

model += x["A"] - M * y <= 0

# -----------------------------------
# Solution
# -----------------------------------
model.solve ()

print('Status:', LpStatus[model.status])

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# Status: Optimal
# car_A = 7.0
# car_B = 270.0
# y = 1.0
# Maximized total profit =  4995000.0

# %% [markdown]
# ## Presentation of the IF-THEN Alex Fleischer Bus Problem
#
# Found at : https://stackoverflow.com/questions/59850692/how-to-write-a-conditional-constraint-in-pulp
#
# <div style="text-align:center">
# <img src="img/fleischer.png" width="500">
# </div>
#
# 300 kids need to travel to the london zoo, The school may rent 40 seats and 30 seats buses for 500dollars and 400dollars, How many buses of each to minimize cost ?
# If then constraint : if nBbus40 more than 3, then nbBus30 more than 7.
#
# Using this great example, we have 3 differents kind of codes with same solutionss, It confirms that it is the right BIGM syntax, because in the third code, IF THEN Cplex internal feature finds the same solution than the Pulp BigM formulation .
#
# <b>Instance table : </b>
#
#  <table>
#   <tr>
#     <th><b>Bus</b></th>
#     <th>nBbus30</th>
#     <th>nBbus40</th>
#     <th>Kids</th>
#   </tr>
#   <tr>
#     <td>Seats</td>
#     <td>30</td>
#     <td>40</td>
#     <td>300</td>
#   </tr>
#   <tr>
#     <tr>
#     <td>Cost</td>
#     <td>400</td>
#     <td>500</td>
#
#   </tr>
#
# </table>
#
# <b> Math model: </b>
#
# $$
# Min(Z) = \sum_{j=1}^{2} c_{j}.x_{j}
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{c} s_{j}.x_{j} <= 300
# $$
#
#
# $$
#  \begin{equation}
#   A =
#     \begin{cases}
#       0 & \text{for x1 < 3}\\
#
#
#       1 & \text{for x1 > 3}\\
#
#     \end{cases}
#   \end{equation}
# $$
#
# $$
#  \begin{equation}
#   B =
#     \begin{cases}
#       0 & \text{for x2 < 7}\\
#
#
#       1 & \text{for x2 > 7}\\
#
#     \end{cases}
#   \end{equation}
# $$
#
# $$
# x \in  ℕ
# $$
#
# $$
# A,B \in \{0,1\}
# $$
#
# $$
# where
# $$
#
# $$
#  x_{j} = number \thinspace of \thinspace bus \thinspace to \thinspace pick
# $$
# $$
#  c_{j} = cost \thinspace  per \thinspace x_{j}  \thinspace bus
# $$
# $$
#  s_{j} = sits \thinspace  per \thinspace x_{j}  \thinspace bus
# $$
# $$
#  A = Apply \thinspace conditional \thinspace  binary \thinspace variable \thinspace per \thinspace x_{2}
# $$
# $$
#  B = Apply \thinspace conditional \thinspace  binary \thinspace variable \thinspace per \thinspace x_{1}
# $$
#
#
#
#
# <b>Alex Fleischer Using Pulp with Big M constraints:</b>

# %%
import pulp
import cplex

bus_problem = pulp.LpProblem("bus", pulp.LpMinimize)

nbBus40 = pulp.LpVariable('nbBus40', lowBound=0, cat='Integer')
nbBus30 = pulp.LpVariable('nbBus30', lowBound=0, cat='Integer')

# Objective function
bus_problem += 600 * nbBus40 + 480 * nbBus30, "cost"

# Constraints
bus_problem += 40 * nbBus40 + 30 * nbBus30 >= 300

bus_problem.solve()
print(pulp.LpStatus[bus_problem.status])

for variable in bus_problem.variables():
    print ("{} = {}".format(variable.name, variable.varValue))

print("with if nb buses 40 more than 3  then nbBuses30 more than 7")

M=100

#if then constraint

A = pulp.LpVariable('A', lowBound=0, cat='Binary')
B = pulp.LpVariable('B', lowBound=0, cat='Binary')

bus_problem += A<=B

bus_problem += nbBus40-2<=M*(A)
bus_problem +=nbBus40-3>=-M*(1-A)
bus_problem +=nbBus30-6<=M*(B)
bus_problem +=nbBus30-7>=-M*(1-B)

bus_problem.solve()
print(pulp.LpStatus[bus_problem.status])

for variable in bus_problem.variables():
    print ("{} = {}".format(variable.name, variable.varValue))
# Out:
# Optimal
# nbBus30 = 2.0
# nbBus40 = 6.0
# with if nb buses 40 more than 3  then nbBuses30 more than 7
# Optimal
# A = 0.0
# B = 1.0
# nbBus30 = 10.0
# nbBus40 = 0.0

# %% [markdown]
# <b> Alex Fleischer Using Cplex with Big M:</b>

# %%
from docplex.mp.model import Model

mdl = Model(name='buses')
nbbus40 = mdl.integer_var(name='nbBus40')
nbbus30 = mdl.integer_var(name='nbBus30')

A = mdl.binary_var(name='A')
B = mdl.binary_var(name='B')


mdl.add_constraint(nbbus40*40 + nbbus30*30 >= 300, 'kids')
mdl.minimize(nbbus40*500 + nbbus30*400)

mdl.solve()

for v in mdl.iter_integer_vars():
   print(v," = ",v.solution_value)

print()
print("with if nb buses 40 more than 3  then nbBuses30 more than 7")

M=100

#if then constraint

mdl.add_constraint(A<=B)
mdl.add_constraint(nbbus40-2<=M*(A))
mdl.add_constraint(nbbus40-3>=-M*(1-A))
mdl.add_constraint(nbbus30-6<=M*(B))
mdl.add_constraint(nbbus30-7>=-M*(1-B))

mdl.minimize(nbbus40*500 + nbbus30*400)

mdl.solve()

for v in mdl.iter_binary_vars():
    print(v," = ",v.solution_value)

for v in mdl.iter_integer_vars():
    print(v," = ",v.solution_value)
# Out:
# nbBus40  =  6.0
# nbBus30  =  2.0
#
# with if nb buses 40 more than 3  then nbBuses30 more than 7
# A  =  0
# B  =  1.0
# nbBus40  =  0
# nbBus30  =  10.0

# %% [markdown]
# <b>Alex Fleischer Using Cplex features:</b>

# %%
from docplex.mp.model import Model

mdl = Model(name='buses')
nbbus40 = mdl.integer_var(name='nbBus40')
nbbus30 = mdl.integer_var(name='nbBus30')
mdl.add_constraint(nbbus40*40 + nbbus30*30 >= 300, 'kids')
mdl.minimize(nbbus40*500 + nbbus30*400)

mdl.solve()

for v in mdl.iter_integer_vars():
   print(v," = ",v.solution_value)


print("with if nb buses 40 more than 3  then nbBuses30 more than 7")

#if then constraint
mdl.add_constraint(mdl.if_then(nbbus40>=3,nbbus30>=7))

mdl.minimize(nbbus40*500 + nbbus30*400)

mdl.solve()

for v in mdl.iter_integer_vars():
    print(v," = ",v.solution_value)
# Out:
# nbBus40  =  6.0
# nbBus30  =  2.0
# with if nb buses 40 more than 3  then nbBuses30 more than 7
# nbBus40  =  0
# nbBus30  =  10.0

# %% [markdown]
# ## Extension of the cars product mix example
#
# Now that I have a guide, let's extend our 2.1 cars product mixe model with the Alex Fleischer style .
#
# Here is our new constraint :
# <b>If produced cars A >= 5 then produced cars B <= 50</b>
#
# Table Instance :
#
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#   </table>
#
#
#   ## Solution using CPlex and the If then internal feature
#
#   <div style="text-align:center">
# <img src="img/IBM_CPLEX_0.png">
# </div>

# %%
# -----------------------------------
# Import from CPLEX
# -------- ---------------------------
import cplex
import docplex.mp
from docplex.mp.model import Model

# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = Model(name='Problem', log_output=True)

# -----------------------------------
# Decision variables
# -----------------------------------
A = model.integer_var(name='A')
B = model.integer_var(name='B')

# -----------------------------------
# Z Objective function 
# -----------------------------------
model.maximize(20000 * A  + 18000 * B  )

# -----------------------------------
# Constraints
# -----------------------------------
model.add_constraint(20 * A + 18 * B <= 5000)
model.add_constraint(10 * A + 8 * B <= 6000)

# -----------------------------------
# Conditional Constraint
# -----------------------------------
model.add_constraint(model.if_then(A >= 5, B <= 50))

# -----------------------------------
# Solution
# ----------- ------------------------
model.parameters.mip.display.set(0)
sol_model = model.solve()
model.print_solution()
# Out:
# Version identifier: 22.1.1.0 | 2023-02-09 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_MIP_Display                             0
# objective: 5000000
# status: OPTIMAL_SOLUTION(2)
#   A=205
#   B=50

# %% [markdown]
# ## Solution using Python Pulp Alex Fleischer BigM méthod
#
# Now, We want the same thing, using Python Pulp .
# If everything's ok, solution should be the same than the Cplex one.
# (Still to be reviewed -  <span style="color:red">Warning, still under review and changes</span>)
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
# -----------------------------------
# Import from Python Pulp
# -------- ---------------------------
from pulp import *
# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )
# -----------------------------------
# Decision variables
# -----------------------------------
A = LpVariable ( "A" , lowBound = 0 , cat = 'Integer' ) 
B = LpVariable ( "B" , lowBound = 0 , cat = 'Integer' ) 
# -----------------------------------
# Objective function R
# -----------------------------------
model += 20000 * A + 18000 * B
# -----------------------------------
# Constraints
# -----------------------------------
model += 20 * A + 18 * B <= 5000 , "k_inventory"
model += 10 * A + 8 * B <= 6000 , "z_inventory"

# -----------------------------------
# Conditional Constraint
# -----------------------------------

# If then constraint - Alex Fleischer style

# BigM value
M = 1000

R = pulp.LpVariable('R', lowBound=0, cat='Binary')
T = pulp.LpVariable('T', lowBound=0, cat='Binary')

model += R>=T

model +=A-4<=M*(R)
model +=A-5>=-M*(1-R)
model +=B-49>= M*(T)
model +=B-50<=-M*(1-T)

print("If produced cars A > 5 then produced cars B < 50")

# -----------------------------------
# Solution
# ----------- ------------------------
model.solve ()

#  Printing variables that have their values optimized
for v in model . variables ():
    print( v . name , "=" , v . varValue )

# optimized objective function value is printed to the screen 
print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# If produced cars A > 5 then produced cars B < 50
# A = 205.9
# B = 49.0
# R = 0.0
# T = 0.0
# Maximized total profit =  5000000.0

# %% [markdown]
# ## <b>7.D OR example</b>
#
# Ok, now, let's try out this new logical <b>OR</b> constraint : <b>Produced cars A <= 20 OR A >=100</b>
#
# We have this great stackoverflow post :
# - https://stackoverflow.com/questions/56710025/how-to-implement-logical-or-constraint-in-cplex-python
# And the Pan Li - Chinese university of Hong Kong doc:
# - https://www.math.cuhk.edu.hk/course_builder/1415/math3220/L2%20(without%20solution).pdf.
#
# Instance:
# <b>Instance</b>:
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#
# </table>
#
# Using Cplex
#
#   <div style="text-align:center">
# <img src="img/IBM_CPLEX_0.png">
# </div>

# %%
# -----------------------------------
# Import from CPLEX
# -------- ---------------------------
import cplex
import docplex.mp
from docplex.mp.model import Model

# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = Model(name='Problem', log_output=True)

# -----------------------------------
# Decision variables
# -----------------------------------
A = model.integer_var(name='A')
B = model.integer_var(name='B')

option1=model.binary_var(name='option1')
option2=model.binary_var(name='option2')

# -----------------------------------
# Z Objective function 
# -----------------------------------
model.maximize(20000 * A  + 18000 * B)

# -----------------------------------
# Constraints
# -----------------------------------
model.add_constraint(20 * A + 18 * B <= 5000)
model.add_constraint(10 * A + 8 * B <= 6000)

# -----------------------------------
# Conditional Constraint
# -----------------------------------
model.add(option1==(A<=20))
model.add(option2==(A>=100))
model.add(1==model.logical_or(option1,option2))

# -----------------------------------
# Solution
# ----------- ------------------------
model.parameters.mip.display.set(0)
sol_model = model.solve()
print("with car A less than 20 or more than 100")
model.print_solution()
# Out:
# Version identifier: 22.1.1.0 | 2023-02-09 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_MIP_Display                             0
# with car A less than 20 or more than 100
# objective: 5000000
# status: OPTIMAL_SOLUTION(2)
#   A=250
#   option2=1

# %% [markdown]
# And now, like in the Hong Kong university doc, let's do this same constraint : <b>Produced cars A <= 20 OR A >=100 </b>with the BigM technic, using Pulp.
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
# -----------------------------------
# Import from Python Pulp
# -------- ---------------------------
from pulp import *
# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )
# -----------------------------------
# Decision variables
# -----------------------------------
A = LpVariable ( "A" , lowBound = 0 , cat = 'Integer' )
B = LpVariable ( "B" , lowBound = 0 , cat = 'Integer' ) 
w = LpVariable ( "w" , lowBound = 0 , cat= 'Binary' )
# -----------------------------------
# Objective function R
# -----------------------------------
model += 20000 * A + 18000 * B
# -----------------------------------
# Constraints
# -----------------------------------
model += 20 * A + 18 * B <= 5000 , "k_inventory"
model += 10 * A + 8 * B <= 6000 , "z_inventory"

# -----------------------------------
# Conditional Constraint
# -----------------------------------

# Like in the Hong kong university doc
M = 1000
model += A <= 20 + M * (1 - w)
model += A >= 100 - M * w


# -----------------------------------
# Solution
# ----------- ------------------------
model.solve ()

print("with car A less than 20 or more than 100")
#  Printing variables that have their values optimized
for v in model . variables ():
    print( v . name , "=" , v . varValue )

# optimized objective function value is printed to the screen 
print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# with car A less than 20 or more than 100
# A = 250.0
# B = 0.0
# w = 0.0
# Maximized total profit =  5000000.0

# %% [markdown]
# And now, let's do this same constraint : Produced cars A <= 20 OR A >=100 , but using Python Pulp and the Alex Fleischer technic like in his post.
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
# -----------------------------------
# Import from Python Pulp
# -------- ---------------------------
from pulp import *
# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )
# -----------------------------------
# Decision variables
# -----------------------------------
A = LpVariable ( "A" , lowBound = 0 , cat = 'Integer' ) 
B = LpVariable ( "B" , lowBound = 0 , cat = 'Integer' ) 
# -----------------------------------
# Objective function R
# -----------------------------------
model += 20000 * A + 18000 * B
# -----------------------------------
# Constraints
# -----------------------------------
model += 20 * A + 18 * B <= 5000 , "k_inventory"
model += 10 * A + 8 * B <= 6000 , "z_inventory"

# -----------------------------------
# Conditional Constraint
# -----------------------------------

# Like in the Alex Fleischer stackOverflow post
# mdl.add((nbbus40<=3) + (nbbus40>=7) >=1)
model += ((A<=20) + (A>=100) >=1)

# -----------------------------------
# Solution
# ----------- ------------------------
model.solve ()

print("with car A less than 20 or more than 100")
#  Printing variables that have their values optimized
for v in model . variables ():
    print( v . name , "=" , v . varValue )

# optimized objective function value is printed to the screen 
print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# with car A less than 20 or more than 100
# A = 7.0
# B = 270.0
# Maximized total profit =  5000000.0

# %% [markdown]
# ## <b>7.5 AND example</b>
#
# Comin' soon

# %% [markdown]
# ## <b>7.6 Restricting decisions variables to a set of values.</b>
#
# Say the A cars production can only take one of the following values : {40,80,160}
#
# <b>Instance</b>:
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#
# </table>
#
# <b>Logical constraint</b> :<br>
# A = 40w1 + 80w2 + 160w3<br>
# w1 + w2 + w3 = 1<br>
# wi ∈ {0, 1}for i = 1 to 3.<br>
#
# <b>Math model</b> :
# $$
# Max (Z) = \sum_{j=1}^{2} p_{j}.x_{j}
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{2} a_{ij}.x_{j} <= s_{i} \thinspace for \thinspace i = 1,2
# $$
#
# $$
#   w_{1} + w_{2} + w_{3} = 1
# $$
#
# $$
# A = 40w_{1} + 80w_{2} + 160w_{3}
# $$
#
# $$
# x \in  ℕ
# $$
#
# $$
#
# w_{i} \in {0, 1} \thinspace for \thinspace i \thinspace = \thinspace 1 \thinspace to \thinspace 3
# $$
#
# $$
# where
# $$
#
# $$
#  x_{j} = number \thinspace of \thinspace produced \thinspace cars
# $$
# $$
#  p_{j} = profit \thinspace  per \thinspace x_{j}  \thinspace car
# $$
# $$
#  a_{ij} = needed \thinspace supply \thinspace per  \thinspace car
# $$
# $$
#  s_{i} =  inventory \thinspace per \thinspace line
# $$
# $$
#  w_{i} = Restriction \thinspace binary \thinspace variables
# $$
#
#
# Pulp code :
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
# -----------------------------------
# Import from Python Pulp
# -------- ---------------------------
from pulp import *
# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )
# -----------------------------------
# Decision variables
# -----------------------------------
A = LpVariable ( "A" , lowBound = 0 , cat = 'Integer' ) 
B = LpVariable ( "B" , lowBound = 0 , cat = 'Integer' ) 
w1 = LpVariable ( "w1" , lowBound = 0 , cat= 'Binary' )
w2 = LpVariable ( "w2" , lowBound = 0 , cat= 'Binary' )
w3 = LpVariable ( "w3" , lowBound = 0 , cat= 'Binary' )
# -----------------------------------
# Objective function 
# -----------------------------------
model += 20000 * A + 18000 * B
# -----------------------------------
# Constraints
# -----------------------------------
model += 20 * A + 18 * B <= 5000 , "k_inventory"
model += 10 * A + 8 * B <= 6000 , "z_inventory"
# -----------------------------------
# Logical restriction Constraint
# -----------------------------------
model += A == 40 * w1 + 80 * w2 + 160 * w3
model += w1 + w2 + w3 == 1
# -----------------------------------
# Solution
# ----------- ------------------------
model.solve ()
print(LpStatus)
print('Status:', LpStatus[model.status])
print("with A produced cars can only take one of the following values : {40,80,160}")
#  Printing variables that have their values optimized
for v in model . variables ():
    print( v . name , "=" , v . varValue )

# optimized objective function value is printed to the screen 
print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# {0: 'Not Solved', 1: 'Optimal', -1: 'Infeasible', -2: 'Unbounded', -3: 'Undefined'}
# Status: Optimal
# with A produced cars can only take one of the following values : {40,80,160}
# A = 160.0
# B = 100.0
# w1 = 0.0
# w2 = 0.0
# w3 = 1.0
# Maximized total profit =  5000000.0

# %% [markdown]
# ## <b>7.7 Restricting a variable to take on discontinuous values.</b>
#
# Say the A cars production can only take a 0 value or being between 20 < A < 80
#
# <b>Instance</b>:
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#
# </table>
#
# <b>Logical constraint</b> :<br>
# <div >
# <img src="img/etendue.png" width="200">
# </div>
# <div >
# <img src="img/etendue2.png" width="200">
# </div>
#
# <b>Math model</b> :<br>
# $$
# Max (Z) = \sum_{j=1}^{2} p_{j}.x_{j}
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{2} a_{ij}.x_{j} <= s_{i} \thinspace for \thinspace i = 1,2
# $$
#
# $$
#  \begin{equation}
#   y =
#     \begin{cases}
#       0 & \text{for A = 0}\\
#
#
#       1 & \text{for 20 < A < 80}\\
#
#     \end{cases}
#   \end{equation}
# $$
#
# $$
# x \in  ℕ
# $$
#
# $$
# y \in \{0,1\}
# $$
#
# $$
# where
# $$
#
# $$
#  x_{j} = number \thinspace of \thinspace produced \thinspace cars
# $$
# $$
#  p_{j} = profit \thinspace  per \thinspace x_{j}  \thinspace car
# $$
# $$
#  a_{ij} = needed \thinspace supply \thinspace per  \thinspace car
# $$
# $$
#  s_{i} =  inventory \thinspace per \thinspace line
# $$
# $$
#  y = binary \thinspace discontinuous \thinspace trigger
# $$
#
# Pulp code :
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
# -----------------------------------
# Import from Python Pulp
# -------- ---------------------------
from pulp import *
# -----------------------------------
# Type of problem
# -----------------------------------
# We choose to solve a Maximization problem
model = LpProblem ( 'Problem' , LpMaximize )
# -----------------------------------
# Decision variables
# -----------------------------------
A = LpVariable ( "A" , lowBound = 0 , cat = 'Integer' ) 
B = LpVariable ( "B" , lowBound = 0 , cat = 'Integer' ) 
y = LpVariable ( "y" , lowBound = 0 , cat= 'Binary' )
# -----------------------------------
# Objective function 
# -----------------------------------
model += 20000 * A + 18000 * B
# -----------------------------------
# Constraints
# -----------------------------------
model += 20 * A + 18 * B <= 5000 , "k_inventory"
model += 10 * A + 8 * B <= 6000 , "z_inventory"
# -----------------------------------
# Logical Constraint
# -----------------------------------
model += 20 * y <= A 
model += A <= 80 * y
# -----------------------------------
# Solution
# ----------- ------------------------
model.solve ()
print('Status:', LpStatus[model.status])
print(" A cars production can only take a 0 value or being between 20 < A < 80")
#  Printing variables that have their values optimized
for v in model . variables ():
    print( v . name , "=" , v . varValue )

# optimized objective function value is printed to the screen 
print ( "Maximized total profit = " , value ( model.objective ) )
# Out:
# Status: Optimal
#  A cars production can only take a 0 value or being between 20 < A < 80
# A = 79.0
# B = 190.0
# y = 1.0
# Maximized total profit =  5000000.0

# %% [markdown]
# ## <b> 7.8 Penalty constraints.</b>
#
# Penalty type constraints (or called elastic with python pulp) allow constraints to be overridden in return for a penalty. While in the normal case a constraint is strict, here it can be slightly exceeded, by defining a negative and positive range.
#
# Example:
# Let's say that if the number of A cars produced is below 5 or exceeds 100, a penalty is applied.
#
# <b>Instance</b>:
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#
# </table>
#
# Python Pulp example :

# %%
# Comin' soon

# %% [markdown]
# ## <b> 7.9 Discontinuous and piecewize costs functions.</b>
#
# - Linear proportional, convex and concave cost constraint difference example.
#
# To explain all this, we will start with a very simple example.<br>
# Let's admit that the cost of shipping an object is proportional to the number of objects sent. The cost of sending a single item is 1 dollar, so if we send 100 items, the shipping cost is 100 dollars. Let's draw a graph to understand that.

# %%
import matplotlib.pyplot as plt
import math

x_cords = range(0,100)
linear_cost = [x * 1 for x in x_cords] 
plt.plot(x_cords, linear_cost, label="Linear shipping price")
plt.xlabel("items")
plt.ylabel("shipping price")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Let's imagine that shipping costs decrease by a percentage depending on the number of items x
#
# Let's choose a 20% percentage. We can see that it's still linear, meaning we can inject this in a linear optimization.

# %%
import matplotlib.pyplot as plt
import math

x_cords = range(0,100)
# Shipping price per item is 1 $
y_lin = [x * 1 for x in x_cords]
# Shipping price per item is 1 $ menus 20 % per x
y_cords = [ 1 * x -  ( 1 * x * 20 / 100) for x in x_cords] 
plt.plot(x_cords, y_lin, "-b", label="Linear shipping price")
plt.plot(x_cords, y_cords, label="20 % discount per x")
plt.xlabel("Items")
plt.ylabel("Shipping price")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Now, we want a more complex shipping price discount definition.
#
# Here we have an example of concave and convex functions, which are no longer linear. The orange function makes no sense in this case but could make sense in some other cases. We will see later that theses convexes and concaves functions can be linearized by creating breakpoints and ranges, it is called  a " Piecewize function ".

# %%
import matplotlib.pyplot as plt
import math

x_cords = range(0,100)
# Shipping price per item is 1 $
y_lin = [x * 1 for x in x_cords]
# More complex shipping discount
y_cords = [ x * ( 1 - x / 300) for x in x_cords] 
# More complex shipping increase
y_conv = [ x * ( 1 + x / 300) for x in x_cords] 
plt.plot(x_cords, y_lin, "-b", label="Linear shipping price")
plt.plot(x_cords, y_cords, label="Concave shipping price discount")
plt.plot(x_cords, y_conv, label="Convex shipping price increase")
plt.xlabel("Items")
plt.ylabel("Shipping price")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# <b>DIscontinuous shipping prices</b>
# Now in real life, we can set the shipping price by considering breakpoints, for example, from 0 to 10 objects sent, the price is 1 dollar per object, then from 10 to 50 objects sent, the price is 0.80 dollars, then from 50 to 100, the price is 0.70 dollars, for all x objects. It is a non-linear function.
#
# Let's draw this function, for a better understanding :

# %%
import matplotlib.pyplot as plt
plt.plot([0, 9, 10, 49,50,100], [1,1,0.8, 0.8, 0.7 ,0.7])
plt.xlabel('Items')
plt.ylabel('Shipping price per item')
plt.show()

# %% [markdown]
# This modeling is also useful in a production mixe context :
#
# Here, we can see that the production cost of an object A is 20 dollars up to 20 objects produced, then 30 dollars up to 50 objects produced, then 50 dollars as soon as the production threshold of 50 objects is exceeded, up to 100.

# %%
import matplotlib.pyplot as plt
plt.plot([0, 19, 20, 49,50,100], [20,20,30, 30, 50 ,50])
plt.xlabel('Items A')
plt.ylabel('Production cost expressed in dollars')
plt.show()

# %% [markdown]
# Now, is there a way to deal with this discontinuous pricing inside of solvers ?
# Yes, Cplex can handle it :
#
# <b>Instance</b>:
#  <table>
#   <tr>
#     <th><b>Car</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>Inventory</th>
#   </tr>
#   <tr>
#     <td>K supplies</td>
#     <td>20</td>
#     <td>18</td>
#      <td>5000</td>
#   </tr>
#   <tr>
#     <td>Z supplies</td>
#     <td>10</td>
#     <td>8</td>
#      <td>6000</td>
#   </tr>
#     <tr>
#     <td>Profit</td>
#     <td>20000</td>
#     <td>18000</td>
#   </tr>
#
# </table>
#
# Let's add theses discontinuous costs :

# %%
import matplotlib.pyplot as plt
plt.plot([0, 19, 20, 49,50,100], [200,200,300, 300, 500 ,500], "-b", label="CARS A")
plt.plot([0, 19, 20, 49,50,100], [250,250,350, 350, 550 ,550], "-r", label="CARS B")
plt.xlabel('Cars')
plt.ylabel('Production cost')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# <b> Math model </b><br>
# Comin'soon

# %% [markdown]
# <b> Cplex solution</b><br>
# Now, let's solve the optimization, using the cplex discontinuous costs feature.

# %%
# -----------------------------------
# Import from CPLEX
# -------- ---------------------------
import cplex
import docplex.mp
from docplex.mp.model import Model
from docplex.util.environment import get_environment

# -----------------------------------
# Setting prob
# -----------------------------------
model = Model(name='Problem', log_output=True)

# -----------------------------------
# Decision variables
# -----------------------------------
A = model.integer_var(name='A')
B = model.integer_var(name='B')

# -----------------------------------
# Discontinuous costs functions
# -----------------------------------

# STEP 1 : CARS A function
# 0 to 20 cars A produced = cost -> 200
# 20 to 50 cars A produced = cost -> 300
# more than 50 cars A produced = cost -> 500
fA = model.piecewise(0, [(0, 200), (20, 300), (50, 500)],1)

# STEP 2 : CARS B function
# 0 to 20 cars A produced = cost -> 250
# 20 to 50 cars A produced = cost -> 350
# more than 50 cars A produced = cost -> 550
fB = model.piecewise(0, [(0, 250), (20, 350), (50, 550)],1)

# -----------------------------------
# Objective function R
# -----------------------------------
model.maximize(20000 * A + 18000 * B - fA(A) - fB(B))

# -----------------------------------
# Constraints
# -----------------------------------
model.add_constraint(20 * A + 18 * B <= 5000)
model.add_constraint(10 * A + 8 * B <= 6000)

# -----------------------------------
# Solution
# ----------- ------------------------
model.parameters.mip.display.set(0)
sol_model = model.solve()
model.print_solution()
# Out:
# Version identifier: 22.1.1.0 | 2023-02-09 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_MIP_Display                             0
# objective: 4999050.000
# status: OPTIMAL_SOLUTION(2)
#   A=250

# %% [markdown]
# ## Piecewize functions
#
# Sometimes we cannot use discontinuous costs but we must use a piecewize function.

# %% [markdown]
# # <b>8. Modeling of a Knapsack problem </b>
#
#
# <div style="text-align:center">
# <img src="img/388_618195ce25-luca-faloni_weekender-leather-bag_made-in-italy_cognac_37089-full.webp" width="200">
# </div>
#
# <b>Introduction</b><br>
# I have a bag that can carry a maximum weight called W, what items should I take in order to maximize the value in my bag as much as possible?
#
#
#
# <b>Instance</b>
#
#  <table>
#   <tr>
#     <th><b>Item</b></th>
#     <th>A</th>
#     <th>B</th>
#     <th>C</th>
#     <th>D</th>
#     <th>E</th>
#     <th>F</th>
#     <th>G</th>
#     <th>H</th>
#
#   </tr>
#   <tr>
#     <td>Weight</td>
#     <td>20</td>
#     <td>22</td>
#     <td>8</td>
#     <td>5</td>
#     <td>20</td>
#     <td>12</td>
#     <td>16</td>
#     <td>18</td>
#
#   </tr>
#   <tr>
#     <td>Value</td>
#      <td>12</td>
#     <td>11</td>
#     <td>5</td>
#     <td>8</td>
#     <td>12</td>
#     <td>14</td>
#     <td>20</td>
#     <td>17</td>
#
#   </tr>
#
#
# </table>
#
# <b>Math model </b>
# $$
# Max (V) = \sum_{j=1}^{8} v_{j}.x_{j}
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{8} w_{j}.x_{j} <= W \thinspace
# $$
#
# $$
# x_{j} \in \{0,1\}
# $$
#
#
# $$
# where
# $$
#
# $$
#  x_{j} = picked \thinspace item
# $$
# $$
#  w_{j} = weight \thinspace  per \thinspace x_{j}  \thinspace item
# $$
# $$
#  v_{j} = value \thinspace per \thinspace x_{j}  \thinspace item
# $$
#
# $$
#   W = max \thinspace weight \thinspace bag \thinspace can \thinspace carry
# $$
#
# $$
#   x_{j} = binary \thinspace selection \thinspace variable
# $$
#
# <b>Python pulp solution </b>
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
# -----------------------------------
# Instance
# -----------------------------------
X = [ 'A','B','C','D','E','F','G','H' ]
w = { 'A' : 20 , 'B':22,'C':8,'D':5,'E':20,'F':12,'G':16,'H':18}
v = { 'A' : 12 , 'B':11,'C':5,'D':8,'E':12,'F':14,'G':20,'H':17}
W = 50

# -----------------------------------
# Type of problem
# -----------------------------------
model = LpProblem ( 'Problem' , LpMaximize )

# -----------------------------------
# Decisions variables
# -----------------------------------
x = LpVariable . dicts ( "item" , X , lowBound = 0 , cat = 'Binary' )

# -----------------------------------
# Math model
# -----------------------------------

# Objective function, stricly like the Math model
model += lpSum ([ v [ j ] * x [ j ] for j in X ]), "MAXIMIZE_V_FUNCTION"

# Constraints

# 1. Weight constraint, stricly like the Math model
model += lpSum ( [ w [ j ]  * x [ j ]  for j in X ]) <= W

# -----------------------------------
# Solution
# -----------------------------------
# debug
# print(model)

model.solve ()

print('Status:', LpStatus[model.status])

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Maximized knapsack value = " , value ( model.objective ) )
# Out:
# Status: Optimal
# item_A = 0.0
# item_B = 0.0
# item_C = 0.0
# item_D = 0.0
# item_E = 0.0
# item_F = 1.0
# item_G = 1.0
# item_H = 1.0
# Maximized knapsack value =  51.0

# %% [markdown]
# #  <b> 9. Modeling of a blending problem : "The Pittsburgh Steel Problem" by Lindo </b>
#
# Source: https: //www.lindo.com/downloads/lingo_text/10-blending_of_input_materials.pdf
#
# And bests docs : https://www.lindo.com/index.php/ls-downloads/user-manuals
#
# <div style="text-align:center">
# <img src="img/steel1.jpg" width="500">
# </div>
#
#
# <b>Instance</b>
#
#
# <div style="text-align:center">
# <img src="img/blend1.png" >
# </div>
# <div style="text-align:center">
# <img src="img/blend2.png" >
# </div>

# %% [markdown]
# <b>Math model</b>
#
# If you look at my chapter 3, you'll see that the cars decisions variables are located at the top of <b> columns</b> .
# But, in this model, decisions variables are located at the beginning of the <b>rows</b>, so , I will indice them using the <b>i</b> indice, because i is the row number by convention.
# When creating the math model, I already think about the solver code. Maybe, there's a way to weight down the model, using an additional j indice, I'll check that later.
#
# $$
# Min (C) = \sum_{i=1}^{11} c_{i}.x_{i}
# $$
# $$
# s.t
# $$
# $$
# x_{i} <= AA_{i}
# $$
# $$
# \sum_{i=1}^{11} PCarb_{i}.x_{i}  >= batch / 100 * CarbC_{11}
# $$
# $$
# \sum_{i=1}^{11} PCarb_{i}.x_{i}  <= batch / 100 * CarbC_{12}
# $$
# $$
# \sum_{i=1}^{11} PChr_{i}.x_{i}  >= batch / 100 * ChrC_{21}
# $$
# $$
# \sum_{i=1}^{11} PChr_{i}.x_{i}  <= batch / 100 * ChrC_{22}
# $$
# $$
# \sum_{i=1}^{11} PMang_{i}.x_{i}  >= batch / 100 * MangC_{31}
# $$
# $$
# \sum_{i=1}^{11} PMang_{i}.x_{i}  <= batch / 100 * MangC_{32}
# $$
# $$
# \sum_{i=1}^{11} PSil_{i}.x_{i}  >= batch / 100 * SilC_{41}
# $$
# $$
# \sum_{i=1}^{11} PSil_{i}.x_{i}  <= batch / 100 * SilC_{42}
# $$
#
# $$
# batch = \sum_{i=1}^{11} x_{i} = 2000
# $$
#
# $$
# Where
# $$
#
# $$
#  x_{i} = material \thinspace amount \thinspace expressed \thinspace in \thinspace pounds
# $$
# $$
#  c_{i} = cost \thinspace  per \thinspace  x_{i}  \thinspace material \thinspace expressed \thinspace in \thinspace dollars
# $$
# $$
#  AA_{i} = Amount \thinspace available \thinspace per \thinspace  x_{i}  \thinspace material \thinspace expressed \thinspace in \thinspace pounds
# $$
# $$
#  PCarb_{i} = percent \thinspace  carbon \thinspace per \thinspace  x_{i}  \thinspace material \thinspace pound
# $$
# $$
#  PChr_{i} = percent \thinspace  chrome \thinspace per \thinspace  x_{i}  \thinspace material \thinspace pound
# $$
# $$
#  PMang_{i} = percent \thinspace  manganese \thinspace per \thinspace  x_{i}  \thinspace material \thinspace pound
# $$
# $$
#  PSil_{i} = percent \thinspace  silicon \thinspace per \thinspace  x_{i}  \thinspace material \thinspace pound
# $$
# $$
#  batch = needed \thinspace  production \thinspace expressed \thinspace in \thinspace pounds
# $$
#
# $$
#  Quality \thinspace requirements
# $$
# $$
#  CarbC_{i,j} = Carbon \thinspace percentage \thinspace requirement
# $$
# $$
#  ChrC_{i,j} = Chrome \thinspace percentage \thinspace requirement
# $$
# $$
#  MangC_{i,j} = Manganese \thinspace percentage \thinspace requirement
# $$
# $$
#  SilC_{i,j} = Silicon \thinspace percentage \thinspace requirement
# $$

# %% [markdown]
# <b>Python pulp solution </b>
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>
#
# Here is the hard coded part I've done a long time ago, solution is ok, but please wait I'm currently redoing it using the instance and the math model, the right way, using iterations.

# %%
import pulp
from pulp import *

# We want to minimize the cost of 2000 alloy pounds # 1 ton means 2000 pounds in England.
prob = LpProblem("Production_1_ton",LpMinimize)

# We create our decisions
# It means that we should be what are the most judicious to choose and we give them a name for everyone
# This is the number of kg of alloy I used.
# Since the value of the number of kgs can be decimal, we specify that it is a decimal decision variable by writing continuous:
P1 = LpVariable("P1", lowBound = 0,cat='Continuous')
P2 = LpVariable("P2", lowBound = 0,cat='Continuous')
F1 = LpVariable("F1", lowBound = 0,cat='Continuous')
F2 = LpVariable("F2", lowBound = 0,cat='Continuous')
A1 = LpVariable("A1", lowBound = 0,cat='Continuous')
A2 = LpVariable("A2", lowBound = 0,cat='Continuous')
A3 = LpVariable("A3", lowBound = 0,cat='Continuous')
CB = LpVariable("CB", lowBound = 0,cat='Continuous')
S1 = LpVariable("S1", lowBound = 0,cat='Continuous')
S2 = LpVariable("S2", lowBound = 0,cat='Continuous')
S3 = LpVariable("S3", lowBound = 0,cat='Continuous')

# Objective / min function (CI * XI) or XI is expressed in cost by Pounds and CI is expressed in dollars
prob += 0.03 * P1 + 0.0645 * P2 + 0.065 * F1 + 0.061 * F2 + 0.1 * A1 +  0.13  *  A2  +  0.119  *  A3  +  0.08  *  CB  +  0.021  *  S1  +  0.02  *  S2  +  0.0195 * S3, "Cout total "

#!We cannot use more than the following inventory of raw materials (see the Doc Lindo table)
prob += CB <= 20; 
prob += S1 <= 200; 
prob += S2 <= 200; 
prob += S3 <= 200; 

#!----------------- Qual requirements -------------------------------------!
#!Carbon content;Here, 60 means that we need 3% of 2000 pounds, it's 60 (see Doc Lindo's painting)
prob += 0.04 * P1 + 0.15 * CB + 0.004 * S1 + 0.001 * S2 + 0.001 * S3 >= 60; 
prob += 0.04 * P1 + 0.15 * CB + 0.004 * S1 + 0.001 * S2 + 0.001 * S3 <= 70; 
##! Chrome content; 
prob += 0.1 * P2 + 0.2 * A2 + 0.08 * A3 >=  6; 
prob += 0.1 * P2 + 0.2 * A2 + 0.08 * A3 <=  9; 
##! Manganese content; 
prob += 0.009 * P1 + 0.045 * P2 + 0.6 * A1 + 0.09 * A2 + 0.33 * A3 + 0.009 * S1 + 0.003 * S2 + 0.003 * S3 >= 27; 
prob += 0.009 * P1 + 0.045 * P2 + 0.6 * A1 + 0.09 * A2 + 0.33 * A3 + 0.009 * S1 + 0.003 * S2 + 0.003 * S3 <= 33; 
#! Silicon content; 
prob +=0.0225 * P1 + 0.15 * P2 + 0.45 * F1 + 0.42 * F2 + 0.18 * A1 + 0.3 * A2 + 0.25 * A3 + 0.3 * CB >=  54; 
prob += 0.0225 * P1 + 0.15 * P2 + 0.45 * F1 + 0.42 * F2 + 0.18 * A1 + 0.3 * A2 + 0.25 * A3 + 0.3 * CB <=  60; 


#! Finish good requirements; 
# We must specify that the total of our decisions expressed in Pounds must be equal to 2000 pounds is 1 ton absolutely, it is therefore logical, no percentages here.
prob += P1 +  P2 +  F1 +   F2 +  A1 +  A2 +   A3 +  CB + S1 + S2 + S3 ==  2000 , "total"
# print(prob)
prob.solve()
print("Status:", LpStatus[prob.status])

for v in prob.variables():
    print(v.name, "=", v.varValue)

print("Total Cost of Ingredients  = ", value(prob.objective))
# Out:
# Status: Optimal
# A1 = 14.238863
# A2 = 0.0
# A3 = 0.0
# CB = 0.0
# F1 = 0.0
# F2 = 22.062052
# P1 = 1474.2641
# P2 = 60.0
# S1 = 200.0
# S2 = 29.434959
# S3 = 200.0
# Total Cost of Ingredients  =  59.556293652

# %% [markdown]
# We see that the python pulp solution is the same than the Lingo one, looking good, bro.
#
# <div style="text-align:center">
# <img src="img/thumbs-up.jpg" width="100">
# </div>
# Here is the screen cap :
# <div style="text-align:center">
# <img src="img/blend-solution.png" >
# </div>

# %% [markdown]
# <b>Let's iterate with Python Pulp</b>
#
# This first attempt give the same solution than Lingo, but I bet there is a way to weight down the math model using the Aij notation in more astucious way.

# %%
# -----------------------------------
# Instance
# -----------------------------------
X = [ 'P1','P2','F1','F2','A1','A2','A3','CB','S1','S2','S3' ]
c = { 'P1' : 0.03, 'P2':0.0645,'F1': 0.065,'F2': 0.061,'A1':0.1,'A2': 0.13,'A3':0.119,'CB':0.08,'S1':0.021,'S2':0.02,'S3':0.0195}
AA = { 'P1' : 10000, 'P2':10000,'F1':10000,'F2':10000,'A1':10000,'A2':10000,'A3':10000,'CB':20,'S1':200,'S2':200,'S3':200}
PCarb = { 'P1' : 0.04, 'P2':0,'F1':0,'F2':0,'A1':0,'A2':0,'A3':0,'CB':0.015,'S1':0.004,'S2':0.001,'S3':0.001}
PChr = { 'P1' : 0, 'P2':0.1,'F1':0,'F2':0,'A1':0,'A2':0.2,'A3':0.08,'CB':0,'S1':0,'S2':0,'S3':0}
PMang = { 'P1' : 0.009, 'P2':0.045,'F1':0,'F2':0,'A1':0.6,'A2':0.09,'A3':0.33,'CB':0,'S1':0.009,'S2':0.003,'S3':0.003}
PSil = { 'P1' : 0.0225, 'P2':0.15,'F1':0.45,'F2':0.42,'A1':0.18,'A2':0.3,'A3':0.25,'CB':0.3,'S1':0,'S2':0,'S3':0}
QR = [
        [0,0],# Null line to avoid the 0 indice in the math model
        [3.00,3.50],
        [0.30,0.45],
        [1.35,1.65],
        [2.70,3.00]
      ]


batch = 2000

# -----------------------------------
# Type of problem
# -----------------------------------
model = LpProblem ( 'Problem' , LpMinimize )

# -----------------------------------
# Decisions variables
# -----------------------------------
x = LpVariable . dicts ( "material" , X , lowBound = 0 , cat = 'Continuous' )

# -----------------------------------
# Math model
# -----------------------------------

# Objective function, stricly like the Math model
model += lpSum ([ c [ i ] * x [ i ] for i in X ]), "MINIMIZE_C_FUNCTION"

# Constraints

# 1. Inventory amount constraint, stricly like the Math model
for i in X:
    model += x [ i ] <= AA [ i ]

# 2. Pcarb quality requirement
model += lpSum ( [ PCarb [ i ] * x [ i ] for i in X ]) >= batch / 100 * QR[1][0]
model += lpSum ( [ PCarb [ i ] * x [ i ] for i in X ]) <= batch / 100 * QR[1][1]

# 3. Pchr quality requirement
model += lpSum ( [ PChr [ i ] * x [ i ] for i in X ]) >= batch / 100 * QR[2][0]
model += lpSum ( [ PChr [ i ] * x [ i ] for i in X ]) <= batch / 100 * QR[2][1]

# 3. PMang quality requirement
model += lpSum ( [ PMang [ i ] * x [ i ] for i in X ]) >= batch / 100 * QR[3][0]
model += lpSum ( [ PMang [ i ] * x [ i ] for i in X ]) <= batch / 100 * QR[3][1] 

# 3. PSil quality requirement
model += lpSum ( [ PSil [ i ] * x [ i ] for i in X ]) >= batch / 100 * QR[4][0]
model += lpSum ( [ PSil [ i ] * x [ i ] for i in X ]) <= batch / 100 * QR[4][1]

# 4. One ton (2000 pounds) must be produced
model += lpSum ( [ x [ i ] for i in X ]) == 2000

# -----------------------------------
# Solution
# -----------------------------------
# debug
# print(model)
model.solve ()

print('Status:', LpStatus[model.status])

for v in model . variables ():
    print( v . name , "=" , v . varValue )

print ( "Minimized blending value of 2000 pounds material, taking care of Quality requirements = " , value ( model.objective ) )
# Out:
# Status: Optimal
# material_A1 = 14.238863
# material_A2 = 0.0
# material_A3 = 0.0
# material_CB = 0.0
# material_F1 = 0.0
# material_F2 = 22.062052
# material_P1 = 1474.2641
# material_P2 = 60.0
# material_S1 = 200.0
# material_S2 = 29.434959
# material_S3 = 200.0
# Minimized blending value of 2000 pounds material, taking care of Quality requirements =  59.556293652

# %% [markdown]
# # <b>  10. Modeling of a set cover problem </b>
#
# ## 10.1 Instance : Wikipedia real set cover problem
#
# <div style="text-align:center">
# <img src="img/wikicover.png" width="200">
# </div>
#
# Source : [Wikipedia Set Cover](https://en.wikipedia.org/wiki/Set_cover_problem)
#
# <b>Instance:</b>
# Consider the universe, U = {1, 2, 3, 4, 5} and the collection of sets S = { {1, 2, 3}, {2, 4}, {3, 4}, {4, 5} }. In this example, m is equal to 4, as there are four subsets that comprise this collection. The union of S is equal to U. However, we can cover all elements with only two sets: { {1, 2, 3}, {4, 5} }‍, see picture, but not with only one set. Therefore, the solution to the set cover problem for this U and S has size 2.
#
# <b>How to minimize the number of needed sets and to cover all of the universe elements ?</b>
#
# <b>Math model</b>
# $$
# Min (S) = \sum_{j=1}^{4} x_{j}
# $$
# $$
# s.t
# $$
# $$
#  \sum_{j=1}^{4} x_{i} >= 1 \thinspace ∀ \thinspace  e \in U
# $$
# $$
# x_{j} \in \{0,1\}
# $$
#
# $$
# where
# $$
#
# $$
#  x_{j} = set \thinspace selection
# $$
# $$
#  e_{j} = element
# $$
# $$
#  U = universe
# $$
#
#
#
# <b>Python pulp solution </b>
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
from pulp import *

# -----------------------------------
# Instance
# -----------------------------------
 
sets = ["S1","S2","S3","S4"]

# Adjacency matrix - sets internal description
           # S1,S2,S3,S4
matrix = [  [1,0,0,0], # e1
            [1,0,0,0], # e2
            [1,1,1,0], # e3
            [0,1,0,1], # e4
            [0,0,1,1]  # e5
        ]

# -----------------------------------
# Type of problem
# -----------------------------------
Problem = LpProblem('minimal_cover_sets',LpMinimize)

# -----------------------------------
# Decisions variables
# -----------------------------------
x = LpVariable.dicts("SET", sets, 0, None, LpBinary)

# -----------------------------------
# Math model
# -----------------------------------

# Objective function, stricly like the Math model
Problem += lpSum(x[j] for j in sets)

# Constraint
for j in matrix: # For each matrix line
    Problem += lpSum(j[idx] * x[i] for idx,i in enumerate(sets)) >= 1 

# -----------------------------------
# Solution
# -----------------------------------
print("-------------SoLution----------------")

Problem.solve()

print('Minimized number of sets = ', value(Problem.objective))
 
for i in Problem.variables():
    print('SELECTED SET:',i.name, '=', i.varValue)
# Out:
# -------------SoLution----------------
# Minimized number of sets =  2.0
# SELECTED SET: SET_S1 = 1.0
# SELECTED SET: SET_S2 = 0.0
# SELECTED SET: SET_S3 = 0.0
# SELECTED SET: SET_S4 = 1.0

# %% [markdown]
# We see that the python pulp solution is the same than the Wikipedia one, looking good, bro.
#
# <div style="text-align:center">
# <img src="img/thumbs-up.jpg" width="100">
# </div>

# %% [markdown]
# ## 10.4  Build a connected facility
#
# <b> Instance</b><br>
# Imagine a city with 5 neighborhoods.
#
# <div style="text-align:center">
# <img src="img/setcover3.png" width="300">
# </div>
#
#
# - district 1 is adjacent with 2 and 5
# - district 2 is adjacent with 1 and 5
# - district 3 is adjacent with 4
# - district 4 is adjacent with 5
# - district 5 is adjacent with 1 and 2 and 3 and 4  -> It is so this one to choose
#
# So, if you have to place a distributor, it must be placed in the district 5.
# The goal is to minimize the amount of needed distributors.
#
# <b>Math model</b>
# Comin' soon
#
# <b>Python pulp solution </b>
#
# <div style="text-align:center">
# <img src="img/small-pulp.png" width="100">
# </div>

# %%
# -----------------------------------
# Instance
# -----------------------------------
N = ["N1","N2","N3","N4","N5"]

# -----------------------------------
# Type of problem
# -----------------------------------
Problem = LpProblem('minimal_cover_neighborhood',LpMinimize)

# -----------------------------------
# Decisions variables
# -----------------------------------
x = LpVariable.dicts("NEIGHBORHOOD",N, 0, None, LpBinary)

# -----------------------------------
# Math model
# -----------------------------------

# Objective function, stricly like the Math model
Problem += lpSum(x[j] for j in N)

# Constraints
Problem += x["N1"] + x["N2"] + x["N5"] >= 1
Problem += x["N1"] + x["N2"] + x["N5"] >= 1
Problem += x["N3"] + x["N5"] >= 1
Problem += x["N4"] + x["N5"] >= 1
Problem += x["N2"] + x["N3"] + x["N4"] + x["N5"] >= 1

# -----------------------------------
# Solution
# -----------------------------------


Problem.solve()

print('Minimized number of sets = ', value(Problem.objective))
 
for i in Problem.variables():
    print('SELECTED NEIGBORHOOD:',i.name, '=', i.varValue)
# Out:
# Minimized number of sets =  1.0
# SELECTED NEIGBORHOOD: NEIGHBORHOOD_N1 = 0.0
# SELECTED NEIGBORHOOD: NEIGHBORHOOD_N2 = 0.0
# SELECTED NEIGBORHOOD: NEIGHBORHOOD_N3 = 0.0
# SELECTED NEIGBORHOOD: NEIGHBORHOOD_N4 = 0.0
# SELECTED NEIGBORHOOD: NEIGHBORHOOD_N5 = 1.0

# %% [markdown]
# # <b>11. Employees tasks assignment problem</b>
#
# <b>11.1 Instance</b>
#
# I have 3 employees each with a different salary, and 3 tasks to complete, how can I minimize the overall cost?
#
# <div style="text-align:center">
# <img src="img/assign.png" width="600">
# </div>
#
# Source : https://www.excel-easy.com/examples/assignment-problem.html
#
# <b>11.2 Math model</b>
# Comin' soon
#
# <b>11.3 Python pulp solution</b>

# %%
# -----------------------------------
# Instance
# -----------------------------------

workers=["P1","P2","P3"]
tasks=["T1","T2","T3"]

# Costs matrix
costs=[[40,47,80],
      [72,36,58],
      [24,61,71]]

# -----------------------------------
# Type of problem
# -----------------------------------
prob = LpProblem("Assignment_Problem", LpMinimize) 

# -----------------------------------
# Necessary pre data treatment
# -----------------------------------
costs= makeDict([workers, tasks], costs, 0)

# Creates a list of tuples containing all of the possible assignments
assign = [(w, j) for w in workers for j in tasks]

# -----------------------------------
# Decisions variables
# -----------------------------------
vars = LpVariable.dicts("Assign", (workers, tasks), 0, None, LpBinary)

# -----------------------------------
# Math model
# -----------------------------------
# Objective function
prob += (lpSum([vars[w][j] * costs[w][j] for (w, j) in assign]),"Sum_of_Assignment_Costs",)

# Constraints
# There are row constraints. Each job can be assigned to only one employee.
for j in tasks:
    prob+= lpSum(vars[w][j] for w in workers) == 1

# There are column constraints. Each employee can be assigned to only one job.
for w in workers:
    prob+= lpSum(vars[w][j] for j in tasks) == 1

# -----------------------------------
# Solution
# -----------------------------------
prob.solve()

for v in prob.variables():
    print(v.name, "=", v.varValue)
    
print("Minimized total cost = ", value(prob.objective))
# Out:
# Assign_P1_T1 = 0.0
# Assign_P1_T2 = 1.0
# Assign_P1_T3 = 0.0
# Assign_P2_T1 = 0.0
# Assign_P2_T2 = 0.0
# Assign_P2_T3 = 1.0
# Assign_P3_T1 = 1.0
# Assign_P3_T2 = 0.0
# Assign_P3_T3 = 0.0
# Minimized total cost =  129.0

# %% [markdown]
# We see that the python pulp solution is the same than the ExcelEasy website one, looking good, bro.
#
# <div style="text-align:center">
# <img src="img/thumbs-up.jpg" width="100">
# </div>

# %% [markdown]
# # <b>12. Modeling of a project tasks scheduling problem</b>
#
# Link :
# https://neos-guide.org/case-studies/sc/mfg/project-scheduling-with-cpm/
# https://medium.com/@AILearningHub/linear-optimization-example-project-scheduling-6d31b1396c1d
#
# <b>12.1 Instance</b>

# %%
# Activity 	Duration (weeks) 	Predecessor(s)
# A 	        2 	                none
# B 	        3 	                A
# C 	        3 	                A
# D 	        4 	                C
# E 	        8 	                D
# F 	        6 	                B, E
# G 	        2 	                F
# I             0                   G

# %% [markdown]
# Math model : Comin' soon

# %%
from pulp import *

# -----------------------------------
# Type of problem
# -----------------------------------
model = LpProblem("Tasks_schedule_Problem", LpMinimize) 

# -----------------------------------
# Decisions variables
# -----------------------------------
START  = LpVariable ( "START" , lowBound = 0 , cat = 'Integer' ) 
A = LpVariable ( "A" , lowBound = 0 , cat = 'Integer' ) 
B = LpVariable ( "B" , lowBound = 0 , cat = 'Integer' ) 
C = LpVariable ( "C" , lowBound = 0 , cat = 'Integer' ) 
D = LpVariable ( "D" , lowBound = 0 , cat = 'Integer' ) 
E = LpVariable ( "E" , lowBound = 0 , cat = 'Integer' ) 
F = LpVariable ( "F" , lowBound = 0 , cat = 'Integer' ) 
G = LpVariable ( "G" , lowBound = 0 , cat = 'Integer' ) 
END = LpVariable ( "END" , lowBound = 0 , cat = 'Integer' ) 

# -----------------------------------
# Objective function 
# -----------------------------------
model += A + B + C + D + E + F + G 

# -----------------------------------
# COnstraints
# -----------------------------------
model += START >= 0
model += A >= START + 2
model += B >= A + 3
model += C >= A + 3
model += D >= C + 4
model += E >= D + 8
model += F >= B + 6
model += F >= E + 6
model += G >= F  + 2



# -----------------------------------
# Solution
# -----------------------------------

model.solve()

for v in model.variables():
    print(v.name, "=", v.varValue)
    
print("Reduced T ", value(model.objective))
# Out:
# A = 2.0
# B = 5.0
# C = 5.0
# D = 9.0
# E = 17.0
# F = 23.0
# G = 25.0
# START = 0.0
# Reduced T  86.0

# %% [markdown]
# Good link : https://ibmdecisionoptimization.github.io/tutorials/html/Scheduling_Tutorial.html#Chapter-2.-Modeling-and-solving-a-simple-problem:-house-building
#
# <b>12.1 Instance</b>
# <div style="text-align:center">
# <img src="img/taskslist.png" width="400">
# </div>
#
# <b>12.2 Math model</b><br>
# Comin' soon.
# In this case, the math model must be really well understood before doing anything.
#
# minimize T
#
# <b>Python Pulp solution</b><br>
# Please wait, I'm checking it

# %% [markdown]
# <b>12.3 Python Mip solution</b>

# %%
from itertools import product
from mip import Model, xsum, BINARY

n = 10
p = [0, 35, 15, 40, 15, 5, 10, 5, 10, 5, 5, 0]  
S = [[0, 1],  [1, 2], [1, 3], [1, 4], [2, 5], [3, 5], [3, 8], [3, 9], [4, 6],
[5, 7], [5, 8], [5, 9], [6,10],[7, 10], [8,10], [9,10], [10,11],]
(J, T) = (range(len(p)), range(sum(p)))

print(J)

model = Model(sense="MINIMIZE", solver_name="CBC")

x = [[model.add_var(name="x({},{})".format(j, t), var_type=BINARY) for t in T] for j in J]
print(x[11][1])


model.objective = xsum(t * x[n + 1][t] for t in T)

print(model)

for j in J:
    model += xsum(x[j][t] for t in T) == 1


for (j, s) in S:
    model += xsum(t * x[s][t] - t * x[j][t] for t in T) >= p[j]

model.optimize()

print("Schedule: ")
for (j, t) in product(J, T):
    if x[j][t].x >= 0.99:
        print("Job {}: begins at t={} and finishes at t={}".format(
            j, t, t+p[j]))
print("Makespan = {}".format(model.objective_value))
# Out:
# range(0, 12)
# x(11,1)
# ...
# Schedule:
# Job 0: begins at t=0 and finishes at t=0
# Job 1: begins at t=0 and finishes at t=35
# Job 2: begins at t=39 and finishes at t=54
# Job 3: begins at t=35 and finishes at t=75
# Job 4: begins at t=37 and finishes at t=52
# Job 5: begins at t=75 and finishes at t=80
# Job 6: begins at t=52 and finishes at t=62
# Job 7: begins at t=80 and finishes at t=85
# Job 8: begins at t=80 and finishes at t=90
# Job 9: begins at t=81 and finishes at t=86
# Job 10: begins at t=90 and finishes at t=95
# Job 11: begins at t=95 and finishes at t=95
# Makespan = 95.0

# %% [markdown]
# <b>Python Cplex solution</b>

# %% [markdown]
# # <b>13. Modeling of a maximum flow problem</b>

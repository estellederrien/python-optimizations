# %% [markdown]
# <div style="text-align:center">
# <img src="img/intro_correspondre.png">
# </div>
#
# <b> In this part 4, I will study BIGM again, Docplex Indicators, and study new kinds of problems. </b>
#
# 39. <b> BigM reminders  </b>
#     - Abstract
#     - Instance
#
# 40. <b> New pb  </b>
#     - Abstract
#     - Instance
#     - Math model
#     - Python Pulp solution

# %% [markdown]
# <div style="text-align:center">
# <img src="img/single-var-intro.png" width="600">
# </div>

# %% [markdown]
# ## Introduction.
#
# *** CREATION IN PROGRESS ***<br>
# Notebook created by GITHUB ESTELLE DERRIEN

# %% [markdown]
# ## Summary
#
# 1. Functions Basics
#     - 1.1 Rate of increase between 2 points
#     - 1.2 Cost of production application

# %% [markdown]
# # 1. Basics
#
# - 1.1 Function Rate of increase
#
# Consider f(x) = x² <br>
# The rate of increase between points x0 = 6 and x1 = 9 is:
# $$
# \frac{f(x_{1})-f(x_{0})}{x_{1} - x_{0}}
# $$

# %%
# Plot f(x) = x²
import matplotlib.pyplot as plt
x_cords = range(0,10)
y_cords = [x*x for x in x_cords]
plt.plot(x_cords, y_cords,'b-',label=' f(x) = x² ')
x = [6, 9]
y = [0, 0]
plt.plot(x, y,'r-',label='Range for rate of increase calculation')
plt.legend()
plt.show()


# Function to use
def func(x):
    return x*x

# Increase rate
def increase_rate(x0,x1):
    return (func(x1) - func(x0) ) / (x1 - x0)

# Display result
print(increase_rate(6,9))
# Out:
# 15.0

# %% [markdown]
# <div style="text-align:center">
# <img src="img/intro.png">
# </div>
#
#
# COMIN SOON DURING 2026

# %% [markdown]
# - <h4>Part 3 : Real life applications ( University level)</h4>
#
#     - 1. Second order differential equations
#         - Abstract
#         - Instance
#         - Solution
#     - 2. Partial differential equations
#         - Abstract
#         - Instance
#         - Solution
#     - 3. Heat equation
#         - Abstract
#         - Instance
#         - Solution
#     - 4. Fluid dynamics - Navier Stockes
#         - Abstract
#         - Instance
#         - Solution
#     - 5.  Black Scholes Model Python
#         - Abstract
#         - Instance
#         - Solution
#     - 6. Electromagnetism equation - Maxwell
#         - Abstract
#         - Instance
#         - Solution
#     - 7. Quantum mechanics
#         - Abstract
#         - Instance
#         - Solution
#
# - <h4>Part 4 : Optimizing Differential equations</h4>
